# %%
# !pip install transformers
# !pip install jsonlines
# !pip install python-levenshtein
# !pip install datasets

# %%
from classifiers import TextCNN, TextGRU

# %%
import Levenshtein as Lev
import torch
from torch.utils.data import Dataset as TorchDataset
from typing import Sequence, Dict, Any, List
import json
from tqdm.notebook import tqdm
import torch
from torch.utils.data import DataLoader
from torch.utils.data import Dataset as TorchDataset
import torch.nn.functional as F
import torch.nn as nn
from datasets import load_dataset

# %%
from transformers import AutoTokenizer
from transformers import BertLMHeadModel
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
maskedlm = BertLMHeadModel.from_pretrained('bert-base-uncased')
# Out:
# If you want to use `BertLMHeadModel` as a standalone, add `is_decoder=True.`
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertLMHeadModel: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertLMHeadModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertLMHeadModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# number of batches
# (len(train_dataset) + 64 - 1) // 64

# %%
train_dataset = load_dataset('trec', split='train')
train_dataset = train_dataset.map(
    lambda e: tokenizer(e['text'], truncation=True, padding='do_not_pad'),
    batched=True
    )
test_dataset = load_dataset('trec', split='test')
test_dataset = test_dataset.map(
    lambda e: tokenizer(e['text'], truncation=True, padding='do_not_pad'),
    batched=True
    )

def collate_fn(batch):
    attention_mask, input_ids, label_coarse = [], [], []
    for b in batch:
        attention_mask.append(torch.tensor(b['attention_mask']))
        input_ids.append(torch.tensor(b['input_ids']))
        label_coarse.append(torch.tensor(b['label-coarse']))
    return {'attention_mask':nn.utils.rnn.pad_sequence(attention_mask, batch_first=True, padding_value=0.0),
            'input_ids':nn.utils.rnn.pad_sequence(input_ids, batch_first=True, padding_value=0.0),
            'label-coarse':label_coarse}

trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=1, drop_last=True, collate_fn=collate_fn, shuffle=True)
testloader = torch.utils.data.DataLoader(test_dataset, batch_size=1, drop_last=True, collate_fn=collate_fn, shuffle=True)
# Out:
# Using custom data configuration default
# Reusing dataset trec (/root/.cache/huggingface/datasets/trec/default/1.1.0/1902c380fe66cc215f989888b1b35e8da7e79a3a97520f00dce753fd1f8f5c48)
# Loading cached processed dataset at /root/.cache/huggingface/datasets/trec/default/1.1.0/1902c380fe66cc215f989888b1b35e8da7e79a3a97520f00dce753fd1f8f5c48/cache-0a0c25324a4451d5.arrow
# Using custom data configuration default
# Reusing dataset trec (/root/.cache/huggingface/datasets/trec/default/1.1.0/1902c380fe66cc215f989888b1b35e8da7e79a3a97520f00dce753fd1f8f5c48)
# Loading cached processed dataset at /root/.cache/huggingface/datasets/trec/default/1.1.0/1902c380fe66cc215f989888b1b35e8da7e79a3a97520f00dce753fd1f8f5c48/cache-20fadfc778bf470d.arrow

# %%
class Deep_lev(torch.nn.Module):

    def __init__(self, vocab_size=30522, embedding_dim=128, hidden_dim=128) :
        super().__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_dim, padding_idx=0)
        self.encoder = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.linear = nn.Linear(hidden_dim * 3, 1)


    def encode_sequence(self, sequence):
        embedded_sequence = self.embeddings(sequence)
        out, (ht, ct) = self.encoder(embedded_sequence)
        return ht[-1]

    def get_embeddings(self, onehots_a, onehots_b):
        embs_a = torch.stack([torch.matmul(v, self.embeddings.weight) for v in onehots_a])
        
        return embs_a

    def forward_on_embeddings(self, sequence_a, sequence_b):
        embs_a = self.get_embeddings(sequence_a, sequence_b)
        _, (embedded_sequence_a, _) = self.encoder(embs_a)
        embedded_sequence_a= embedded_sequence_a[-1]
        
        embedded_sequence_b = self.encode_sequence(sequence_b)
        diff = torch.abs(embedded_sequence_a - embedded_sequence_b)
        representation = torch.cat([embedded_sequence_a, embedded_sequence_b, diff], dim=-1)
        approx_distance = self.linear(representation)

        return approx_distance


    def forward(self, sequence_a, sequence_b):
        embedded_sequence_a = self.encode_sequence(sequence_a)
        embedded_sequence_b = self.encode_sequence(sequence_b)
        diff = torch.abs(embedded_sequence_a - embedded_sequence_b)
        representation = torch.cat([embedded_sequence_a, embedded_sequence_b, diff], dim=-1)

        approx_distance = self.linear(representation)

        return approx_distance

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device('cpu')
deep_lev = Deep_lev()
deep_lev.load_state_dict(torch.load('deep_levenstein.pt'))
deep_lev = deep_lev.to(device)

# %%
classifier = TextCNN(vocab_size=tokenizer.vocab_size,
                emb_dim=100,
                n_filters=8,
                filter_sizes=[3,4,5],
                output_dim=6,
                dropout=0.1,
                pad_idx=tokenizer.pad_token_id)

classifier = classifier.to(device)
sub_classifier =  TextGRU(
    vocab_size=tokenizer.vocab_size,
    emb_dim=100,
    hidden_dim=128,
    out_dim=6,
    dropout=0.1,
    pad_idx=tokenizer.pad_token_id
    )
classifier.eval()
classifier.load_state_dict(torch.load('textcnn_trec.pt'))
sub_classifier.load_state_dict(torch.load('textrnn_trec.pt'))
sub_classifier = sub_classifier.to(device)
maskedlm = maskedlm.to(device)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py:61: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))

# %%
def dilma_loss(preds, approx_distance, label, beta = 1.):
    '''
    -log((1-Classifier(x'))) + beta * (1-DL(x, x'))**2 
    '''
    global device
    pred = preds.softmax(1)
    one2 = torch.full(approx_distance.squeeze(1).shape, 5, device=device)
    clf_term = -torch.log(1 - pred[label[0].item()].mean())
    dl_term = beta * ((1 - approx_distance.squeeze(1)).mean()**2)
    return (clf_term.mean() + dl_term).mean()

# %%
import numpy as np
import random 

def mask_tokens(batch, tokenizer):
    batch_masked, masked_inds = [], []
    for b in batch:
        limit = b[b!=tokenizer.pad_token_id].shape[0]
        inds_to_mask = np.random.choice(np.arange(1, limit-1), size=1)
        masked_inds.append(inds_to_mask)
        b_new = b.clone()
        b_new[inds_to_mask] = tokenizer.mask_token_id
        batch_masked.append(b_new)
    return torch.stack(batch_masked), masked_inds

# %%
def categorical_accuracy(preds, y):
    """
    Returns accuracy per batch, i.e. if you get 8/10 right, this returns 0.8, NOT 8
    """
    max_preds = preds.argmax(dim=1, keepdim=True) # get the index of the max probability
    # pred_ = torch.argmax(torch.softmax(preds, dim=1), dim =1)

    # corrrect = pred_[torch.stack(batch['label-coarse']) == 5]
    correct = max_preds.squeeze(1).eq(y)
    correct = correct.detach().to('cpu')
    return correct.sum() / torch.FloatTensor([y.shape[0]])

def get_text_length(batch, tokenizer):
    result = []
    for i in range(batch.shape[1]):
        result.append((sum(batch[:, i] != tokenizer.pad_token_id).item()))
    return torch.tensor(result, dtype=int, device='cpu')

def categorical_accuracy_for_gumbel(preds, y):
    """
    Returns accuracy per batch, i.e. if you get 8/10 right, this returns 0.8, NOT 8
    """
    max_preds = preds.argmax(-1) # get the index of the max probability
    # pred_ = torch.argmax(torch.softmax(preds, dim=1), dim =1)

    # corrrect = pred_[torch.stack(batch['label-coarse']) == 5]
    correct = max_preds.eq(y)
    correct = correct.detach().to('cpu')
    return correct.sum() / torch.FloatTensor([y.shape[0]])

def delete_start_end_tokens(seq):
    return seq[:, 1:-1]

def calculate_wer(text_a, text_b):
    b = set(text_a.split() + text_b.split())
    word2char = dict(zip(b, range(len(b))))

    w1 = [chr(word2char[w]) for w in text_a.split()]
    w2 = [chr(word2char[w]) for w in text_b.split()]

    return Lev.distance(''.join(w1), ''.join(w2))

# %%
optimizer = torch.optim.Adam(maskedlm.parameters(), lr=0.001)
sub_classifier = classifier
# from transformers import AdamW, get_linear_schedule_with_warmup
# optimizer = AdamW(maskedlm.parameters(), lr=1e-3)

# %%
torch.backends.cudnn.enabled = False

# %%
def update_weights(lm_model):
    for parameter in lm_model.parameters():
        parameter.data -= 0.001 * parameter.grad.data
        parameter.grad = None

# %%
from copy import deepcopy

losses = []
classifier.eval()
deep_lev.eval()
n_epoch = 11
num_steps = 8

res = []
for i, batch in enumerate(trainloader):
    if i < 1000:
        maskedlm_ = deepcopy(maskedlm)
        maskedlm_ = maskedlm_.to(device)
        maskedlm_.train()
        # for name, param in maskedlm_.named_parameters():
        #     param.requires_grad = True
        optimizer = torch.optim.Adam(maskedlm_.parameters(), lr=0.001)
        for j in range(num_steps):
            optimizer.zero_grad()
            maskedlm_.zero_grad()
            label = torch.stack(batch['label-coarse']).to(device)
            label = torch.cat(10*[label]).to(device)
            b_input_ids = batch['input_ids'].to(device)
            b_input_mask = batch['attention_mask'].to(device)
            b_masked, masked_inds = mask_tokens(b_input_ids, tokenizer)
            b_masked = b_masked.to(device)
            logits = maskedlm_(b_masked, attention_mask=b_input_mask)
            #get gumbel_samples
            gumbel_samples = torch.cat([torch.nn.functional.gumbel_softmax(logits['logits'], tau = 1.8, hard=True) for _ in range(10)])
            gumbel_samples = gumbel_samples.to(device)
            b_input_ids = torch.cat(10*[b_input_ids]).to(device)
            approx_distance = deep_lev.forward_on_embeddings(gumbel_samples, b_input_ids)
            scores = classifier.forward_on_embeddings(gumbel_samples)
            scores_orig = classifier(b_input_ids)
            scores_orig = scores_orig.to(device)
            loss = dilma_loss(scores.to(device), approx_distance.to(device), label, beta=5)
            loss.backward()

            update_weights(maskedlm_)
            optimizer.step()

        with torch.no_grad():
            label = torch.stack(batch['label-coarse']).to(device)
            label = torch.cat(10*[label]).to(device)
            b_input_ids = batch['input_ids'].to(device)
            b_input_mask = batch['attention_mask'].to(device)
            b_masked, masked_inds = mask_tokens(b_input_ids, tokenizer)
            b_masked = b_masked.to(device)
            logits = maskedlm_(b_masked, attention_mask=b_input_mask)
            #get gumbel_samples
            gumbel_samples = torch.cat([torch.nn.functional.gumbel_softmax(logits['logits'], tau = 1.8, hard=True) for _ in range(10)])
            gumbel_samples = gumbel_samples.to(device)
            b_input_ids = torch.cat(10*[b_input_ids]).to(device)
            scores = classifier.forward_on_embeddings(gumbel_samples)
            scores_orig = classifier(b_input_ids)
            
            res.append({'advs':gumbel_samples.argmax(-1).detach().cpu(),
                        'origs': b_input_ids.detach().cpu(),
                        'scores': scores.softmax(-1).argmax(-1).detach().cpu(),
                        'scores_orig': scores_orig.softmax(-1).argmax(-1).detach().cpu()})
    else:
        break

# %%
stats = []
for x in res:
    out = {'wer': [],
       'adversarial' : [],
       'original' : []}
    if len(x['scores'][x['scores']!=x['scores_orig']]) > 0:
        for i, _ in enumerate(x['scores'][x['scores']!=x['scores_orig']].numpy()):
            out['wer'].append(calculate_wer(' '.join(t for t in [tokenizer.decode(a) for a in x['advs'][:, 1:-1][i, :]]), ' '.join(c for c in [tokenizer.decode(b) for b in x['origs'][:, 1:-1][i, :]])))
            out['adversarial'].append(' '.join(t for t in [tokenizer.decode(a) for a in x['advs'][i, :]]))
            out['original'].append(' '.join(c for c in [tokenizer.decode(b) for b in x['origs'][i, :]]))
        stats.append(out)
    else:
        continue

# %% [markdown]
# Calculate NAD

# %%
nad_value = 0
for x in stats:
    nad_value += 1/min(x['wer']) if min(x['wer'])>0 else 1
print(nad_value * 1/1000)
# Out:
# 0.36394999999999994

# %%
stats
# Out:
# [{'adversarial': ['footing what is the cost of the drugs used in those their ? series',
#    'hostilities what is the cost of the drugs used in the treatments ? ?',
#    'successor what is the cost of the drugs used in the treatments ? of',
#    'fear what is the cost of the drugs used in the treatments ? ?',
#    'ip what is the cost of the drugs used in the treatments ? states',
#    'nightmare what is the cost of the drugs used in these treatments ? is'],
#   'original': ['[CLS] what is the cost of the drugs used in tuberculosis treatments ? [SEP]',
#    '[CLS] what is the cost of the drugs used in tuberculosis treatments ? [SEP]',
#    '[CLS] what is the cost of the drugs used in tuberculosis treatments ? [SEP]',
#    '[CLS] what is the cost of the drugs used in tuberculosis treatments ? [SEP]',
#    '[CLS] what is the cost of the drugs used in tuberculosis treatments ? [SEP]',
#    '[CLS] what is the cost of the drugs used in tuberculosis treatments ? [SEP]'],
#   'wer': [2, 1, 1, 1, 1, 1]},
#  {'adversarial': ['in what do players try to do when the music stops in a game of musical chairs ? )'],
#   'original': ['[CLS] what do players try to do when the music stops in a game of musical chairs ? [SEP]'],
#   'wer': [0]},
#  {'adversarial': ['##0 what sham ##poo aids ec ##ze ##ma , se ##port ##rh ##ea , and ps ##oria ##us ? .',
#    'euro what sham ##poo prevents ec ##ze ##ma , se ##bor ##rh ##ea , and ps ##oria ##sis ? ##gar',
#    'possibly what sham ##poo causes ec ##ze ##ma , se ##bor ##rh ##ea , and ps ##oria ##sis ? don',
#    '##s what sham ##poo causes ec ##ze ##ma , se ##bor ##rh ##ea , and ps ##oria ##sis ? .'],
#   'original': ['[CLS] what sham ##poo prevents ec ##ze ##ma , se ##bor ##rh ##ea , and ps ##oria ##sis ? [SEP]',
#    '[CLS] what sham ##poo prevents ec ##ze ##ma , se ##bor ##rh ##ea , and ps ##oria ##sis ? [SEP]',
#    '[CLS] what sham ##poo prevents ec ##ze ##ma , se ##bor ##rh ##ea , and ps ##oria ##sis ? [SEP]',
#    '[CLS] what sham ##poo prevents ec ##ze ##ma , se ##bor ##rh ##ea , and ps ##oria ##sis ? [SEP]'],
#   'wer': [3, 0, 1, 1]},
#  {'adversarial': ["##ising what is deco ##nst ##ru ' ##ism ? .",
#    '##sk what is deco ##nst ##ru ##ity ##ism ? .'],
#   'original': ['[CLS] what is deco ##nst ##ru ##ction ##ism ? [SEP]',
#    '[CLS] what is deco ##nst ##ru ##ction ##ism ? [SEP]'],
#   'wer': [1, 1]},
#  {'adversarial': ['companies ( of civil war historic . .',
#    'nipple ##υ for civil war battlefield . lonely',
#    'foreigners 18 from civil confederate battlefield . ,',
#    'excluding ( of civil war battlefield . ##f',
#    'was i of civil confederate battlefield . ,',
#    'take memorial in civil war battlefield . ,',
#    'could e of civil field battlefield . weather'],
#   'original': ['[CLS] name a civil war battlefield . [SEP]',
#    '[CLS] name a civil war battlefield . [SEP]',
#    '[CLS] name a civil war battlefield . [SEP]',
#    '[CLS] name a civil war battlefield . [SEP]',
#    '[CLS] name a civil war battlefield . [SEP]',
#    '[CLS] name a civil war battlefield . [SEP]',
#    '[CLS] name a civil war battlefield . [SEP]'],
#   'wer': [3, 2, 3, 2, 3, 2, 3]},
#  {'adversarial': ["tai what green bay packers coach phil ##oso ##phi ##ed : ` ` there ' s nothing that stokes the fire like this ' ' ? ."],
#   'original': ["[CLS] what green bay packers coach phil ##oso ##phi ##zed : ` ` there ' s nothing that stokes the fire like hate ' ' ? [SEP]"],
#   'wer': [2]},
#  {'adversarial': ['##ous what is , pig in a ring ? that',
#    'eyelids what is a pig in a poke ? )'],
#   'original': ['[CLS] what is a pig in a poke ? [SEP]',
#    '[CLS] what is a pig in a poke ? [SEP]'],
#   'wer': [2, 0]},
#  {'adversarial': ['in then shot and killed himself while painting wheat ##field with crows ? .',
#    'pods someone shot and killed himself while painting wheat ##field with crows ? .',
#    'barking he shot and killed himself while painting wheat ##field with crows ? either',
#    'wants and shot and killed himself while painting wheat ##field with crows ? .'],
#   'original': ['[CLS] who shot and killed himself while painting wheat ##field with crows ? [SEP]',
#    '[CLS] who shot and killed himself while painting wheat ##field with crows ? [SEP]',
#    '[CLS] who shot and killed himself while painting wheat ##field with crows ? [SEP]',
#    '[CLS] who shot and killed himself while painting wheat ##field with crows ? [SEP]'],
#   'wer': [1, 1, 1, 1]},
#  {'adversarial': ['##s what is the movie jonathan livingstone . ##gul ##ls ? tighter',
#    '##р what is the movie jonathan people a ##gul ##l ? ##rdon'],
#   'original': ['[CLS] what is the movie jonathan livingstone sea ##gul ##l ? [SEP]',
#    '[CLS] what is the movie jonathan livingstone sea ##gul ##l ? [SEP]'],
#   'wer': [2, 2]},
#  {'adversarial': ['capable what day did hitler be ? give',
#    'announced what proof did hitler was ? pirates',
#    '##ivism what maybe did hitler die ? soldiers',
#    'effect when way did hitler die ? editing',
#    'batted what ... did hitler die ? sat',
#    '. what else did hitler hitler ? bear',
#    'universities what day did hitler die ? judith'],
#   'original': ['[CLS] what year did hitler die ? [SEP]',
#    '[CLS] what year did hitler die ? [SEP]',
#    '[CLS] what year did hitler die ? [SEP]',
#    '[CLS] what year did hitler die ? [SEP]',
#    '[CLS] what year did hitler die ? [SEP]',
#    '[CLS] what year did hitler die ? [SEP]',
#    '[CLS] what year did hitler die ? [SEP]'],
#   'wer': [2, 2, 1, 2, 1, 2, 1]},
#  {'adversarial': ['stalls what is the only modern language that capital ##izes its singular first - person pro ##no ##un ? .'],
#   'original': ['[CLS] what is the only modern language that capital ##izes its singular first - person pro ##no ##un ? [SEP]'],
#   'wer': [0]},
#  {'adversarial': ['elects what is the future of japan ? .',
#    '##ton in is the port of japan ? .',
#    'moe graham is the history of japan ? .',
#    'inhabitants stain is the problem of japan ? .',
#    'funded what is the state of japan ? .'],
#   'original': ['[CLS] what is the population of japan ? [SEP]',
#    '[CLS] what is the population of japan ? [SEP]',
#    '[CLS] what is the population of japan ? [SEP]',
#    '[CLS] what is the population of japan ? [SEP]',
#    '[CLS] what is the population of japan ? [SEP]'],
#   'wer': [1, 2, 2, 2, 1]},
#  {'adversarial': ["blocked who are a baseball team ' s fire ##men ? fear",
#    "weapon who are a baseball team ' s fire ##men ? tee",
#    "area why are a baseball team ' s fire ##men ? roy",
#    "jungle who are a baseball team ' s fire ##men ? hires",
#    "heads you are a baseball team ' s fire ##men ? derry",
#    "en they are a baseball team ' s fire ##men ? ##tyle",
#    "larger why are a baseball team ' s fire ##men ? reasoned",
#    "stomped who are a baseball team ' s fire ##men ? brain"],
#   'original': ["[CLS] what are a baseball team ' s fire ##men ? [SEP]",
#    "[CLS] what are a baseball team ' s fire ##men ? [SEP]",
#    "[CLS] what are a baseball team ' s fire ##men ? [SEP]",
#    "[CLS] what are a baseball team ' s fire ##men ? [SEP]",
#    "[CLS] what are a baseball team ' s fire ##men ? [SEP]",
#    "[CLS] what are a baseball team ' s fire ##men ? [SEP]",
#    "[CLS] what are a baseball team ' s fire ##men ? [SEP]",
#    "[CLS] what are a baseball team ' s fire ##men ? [SEP]"],
#   'wer': [1, 1, 1, 1, 1, 1, 1, 1]},
#  {'adversarial': ['oil who was buffalo bill ? latitude',
#    'trio who was buffalo bill ? trapping',
#    'nato where was buffalo bill ? .',
#    '##real who was the bill ? latitude',
#    'globe where was buffalo bill ? ##jah'],
#   'original': ['[CLS] who was buffalo bill ? [SEP]',
#    '[CLS] who was buffalo bill ? [SEP]',
#    '[CLS] who was buffalo bill ? [SEP]',
#    '[CLS] who was buffalo bill ? [SEP]',
#    '[CLS] who was buffalo bill ? [SEP]'],
#   'wer': [0, 0, 1, 1, 1]},
#  {'adversarial': [') when was the simon shirt ##wai ##sar fire ? him',
#    'club how was the white shirt ##wai shirt fire ? ##sia',
#    'ulrich when was the triangle shirt ##wai hot fire ? ##ott',
#    '##l how was the triangle shirt ##wai pride fire ? me'],
#   'original': ['[CLS] when was the triangle shirt ##wai ##st fire ? [SEP]',
#    '[CLS] when was the triangle shirt ##wai ##st fire ? [SEP]',
#    '[CLS] when was the triangle shirt ##wai ##st fire ? [SEP]',
#    '[CLS] when was the triangle shirt ##wai ##st fire ? [SEP]'],
#   'wer': [2, 3, 1, 2]},
#  {'adversarial': ['. what is a ton is ? you',
#    '" wo is the ton ##me ! i',
#    '27 for is a man ##ne ? and'],
#   'original': ['[CLS] what is a ton ##ne ? [SEP]',
#    '[CLS] what is a ton ##ne ? [SEP]',
#    '[CLS] what is a ton ##ne ? [SEP]'],
#   'wer': [1, 4, 2]},
#  {'adversarial': ["modules what was the name of ` ` the mu ##ppet ##s ' ' ' ? !",
#    "t what was the name of ` ` the mu ##ppet ##s ' ' creator ? .",
#    "neighborhoods what was the name of ` ` the mu ##ppet wrocław ' ' creator ? .",
#    "deserts what was the name of ` ` the lo ##ppet ##s ' ' creator ? ##aday",
#    "state what was the name of ` ` the mu ##ppet ##s ' ' creator ? ."],
#   'original': ["[CLS] what was the name of ` ` the mu ##ppet ##s ' ' creator ? [SEP]",
#    "[CLS] what was the name of ` ` the mu ##ppet ##s ' ' creator ? [SEP]",
#    "[CLS] what was the name of ` ` the mu ##ppet ##s ' ' creator ? [SEP]",
#    "[CLS] what was the name of ` ` the mu ##ppet ##s ' ' creator ? [SEP]",
#    "[CLS] what was the name of ` ` the mu ##ppet ##s ' ' creator ? [SEP]"],
#   'wer': [1, 0, 1, 1, 0]},
#  {'adversarial': ['1828 how more bail ##s are there in a cricket wicket ? )',
#    'puppet how all just ##s are there in a cricket wicket ? who'],
#   'original': ['[CLS] how many bail ##s are there in a cricket wicket ? [SEP]',
#    '[CLS] how many bail ##s are there in a cricket wicket ? [SEP]'],
#   'wer': [1, 2]},
#  {'adversarial': ['cinema what is home banking ? the',
#    'reduction what is home banking ? fitted',
#    'election what is home banking ? highlights',
#    'brian what is home banking ? advanced'],
#   'original': ['[CLS] what is home banking ? [SEP]',
#    '[CLS] what is home banking ? [SEP]',
#    '[CLS] what is home banking ? [SEP]',
#    '[CLS] what is home banking ? [SEP]'],
#   'wer': [0, 0, 0, 0]},
#  {'adversarial': ['total how five humans spreads up a word for my test purposes ? me',
#    'efficiency how what best forms out a word for typing test purposes ? .',
#    'kansas how many words and different a word for language test purposes ? all',
#    'wyatt how each honesty forms up a word for some test purposes ? ##con',
#    'reflect how more defining forms up a word for typing test purposes ? 000'],
#   'original': ['[CLS] how many characters makes up a word for typing test purposes ? [SEP]',
#    '[CLS] how many characters makes up a word for typing test purposes ? [SEP]',
#    '[CLS] how many characters makes up a word for typing test purposes ? [SEP]',
#    '[CLS] how many characters makes up a word for typing test purposes ? [SEP]',
#    '[CLS] how many characters makes up a word for typing test purposes ? [SEP]'],
#   'wer': [4, 4, 4, 4, 3]},
#  {'adversarial': ['vary " sign has a superb pet , even because to recognize its master ? )',
#    'ingredients what foods makes a superb pet , even said to recognize its master ? the',
#    'of ##fish breed makes a superb pet , even said to recognize its master ? .'],
#   'original': ['[CLS] what spider makes a superb pet , even said to recognize its master ? [SEP]',
#    '[CLS] what spider makes a superb pet , even said to recognize its master ? [SEP]',
#    '[CLS] what spider makes a superb pet , even said to recognize its master ? [SEP]'],
#   'wer': [4, 1, 2]},
#  {'adversarial': ['flag what tv game show once saw a contestant admit to kissing his candle in the shower ? .'],
#   'original': ['[CLS] what tv game show once saw a contestant admit to picking his toes in the shower ? [SEP]'],
#   'wer': [2]},
#  {'adversarial': ["##ron what football coach ' s wife was told in the movie run to daylight ? amy",
#    "council what football coach ' s coach was told in the movie run to daylight ? '",
#    "present what football coach ' s line was said in the movie run to goal ? '",
#    "unarmed what football coach ' s perspective was told in the movie run to them ? martin",
#    "leaving what football coach ' s story was told in the movie run to qb ? '",
#    "worth what football coach ' s phrase was told in the film run to love ? ,",
#    "leap what football coach ' s character was told in the movie run to ##gan ? position"],
#   'original': ["[CLS] what football coach ' s story was told in the movie run to daylight ? [SEP]",
#    "[CLS] what football coach ' s story was told in the movie run to daylight ? [SEP]",
#    "[CLS] what football coach ' s story was told in the movie run to daylight ? [SEP]",
#    "[CLS] what football coach ' s story was told in the movie run to daylight ? [SEP]",
#    "[CLS] what football coach ' s story was told in the movie run to daylight ? [SEP]",
#    "[CLS] what football coach ' s story was told in the movie run to daylight ? [SEP]",
#    "[CLS] what football coach ' s story was told in the movie run to daylight ? [SEP]"],
#   'wer': [1, 1, 3, 2, 1, 3, 2]},
#  {'adversarial': ['" what did benny carter know ? invited',
#    'i what was benny carter know ? aba',
#    'subcontinent what did benny carter want ? grown'],
#   'original': ['[CLS] what did benny carter play ? [SEP]',
#    '[CLS] what did benny carter play ? [SEP]',
#    '[CLS] what did benny carter play ? [SEP]'],
#   'wer': [1, 2, 1]},
#  {'adversarial': ['answered " made camera - ready to mean ? a',
#    'go marched were camera - ready powers mean ? standard',
#    'there her was camera - ready to mean ? the',
#    'hosting wisconsin was camera - ready spots mean ? ireland',
#    'hers next could fake - paramilitary things mean ? the',
#    'da dion was camera - ready to mean ? the',
#    '##land . was camera - ready was mean ? attractive',
#    '##ille who was camera - ready to mean ? detective'],
#   'original': ['[CLS] what does camera - ready art mean ? [SEP]',
#    '[CLS] what does camera - ready art mean ? [SEP]',
#    '[CLS] what does camera - ready art mean ? [SEP]',
#    '[CLS] what does camera - ready art mean ? [SEP]',
#    '[CLS] what does camera - ready art mean ? [SEP]',
#    '[CLS] what does camera - ready art mean ? [SEP]',
#    '[CLS] what does camera - ready art mean ? [SEP]',
#    '[CLS] what does camera - ready art mean ? [SEP]'],
#   'wer': [3, 3, 3, 3, 5, 3, 3, 3]},
#  {'adversarial': ['senate where does the u . s . earth most of its energy ? only'],
#   'original': ['[CLS] where does the u . s . get most of its energy ? [SEP]'],
#   'wer': [1]},
#  {'adversarial': ['franz what are , five basic swimming ##kis ? "',
#    'star what are the five basic swimming strokes ? f'],
#   'original': ['[CLS] what are the five basic swimming strokes ? [SEP]',
#    '[CLS] what are the five basic swimming strokes ? [SEP]'],
#   'wer': [2, 0]},
#  {'adversarial': ['##sur what will the six - footed mu ##sca ##rio ##a become when it enters a house ? ,'],
#   'original': ['[CLS] what does the six - footed mu ##sca domestic ##a become when it enters a house ? [SEP]'],
#   'wer': [2]},
#  {'adversarial': ['. what is ch ##rom ##ato ##logy ? rosalie',
#    '##ᄌ what is ste ##rom ##ato ##logy ? )'],
#   'original': ['[CLS] what is ch ##rom ##ato ##logy ? [SEP]',
#    '[CLS] what is ch ##rom ##ato ##logy ? [SEP]'],
#   'wer': [0, 1]},
#  {'adversarial': ["##lc what card suit originally represented the peasants class ? '",
#    'is what card suit originally represented the peasant class ? is',
#    'tradition what card suit ancestral represented the peasant class ? were',
#    'snapped what card suit originally represented the peasant class ? what',
#    '1966 what card suit origin featured the beat class ? 24',
#    'res what card suit originally represented the peasant class ? what'],
#   'original': ['[CLS] what card suit originally represented the peasant class ? [SEP]',
#    '[CLS] what card suit originally represented the peasant class ? [SEP]',
#    '[CLS] what card suit originally represented the peasant class ? [SEP]',
#    '[CLS] what card suit originally represented the peasant class ? [SEP]',
#    '[CLS] what card suit originally represented the peasant class ? [SEP]',
#    '[CLS] what card suit originally represented the peasant class ? [SEP]'],
#   'wer': [1, 0, 1, 0, 3, 0]},
#  {'adversarial': ['garden what is the history of sparta ##cus , the roman warrior and glad ##ia ##tor ? patterns',
#    'strangled what is the history of sparta ##cus , the roman slave and glad ##ia ##tor ? ##don',
#    'british what is the history of sparta ##cus , the roman slave and glad ##ia ##tor ? heroic',
#    'form what is the history of sparta ##cus , the roman slave and glad ##ia ##tor ? ##nen',
#    '47 what is the history of sparta ##cus , the roman slave and glad ##ia ##tor ? wah',
#    'largely what is the history of sparta ##cus , the roman slave and glad ##ia ##tor ? quest',
#    'm what is the history of sparta ##cus , the roman slave and glad ##ia ##tor ? courageous'],
#   'original': ['[CLS] what is the history of sparta ##cus , the roman slave and glad ##ia ##tor ? [SEP]',
#    '[CLS] what is the history of sparta ##cus , the roman slave and glad ##ia ##tor ? [SEP]',
#    '[CLS] what is the history of sparta ##cus , the roman slave and glad ##ia ##tor ? [SEP]',
#    '[CLS] what is the history of sparta ##cus , the roman slave and glad ##ia ##tor ? [SEP]',
#    '[CLS] what is the history of sparta ##cus , the roman slave and glad ##ia ##tor ? [SEP]',
#    '[CLS] what is the history of sparta ##cus , the roman slave and glad ##ia ##tor ? [SEP]',
#    '[CLS] what is the history of sparta ##cus , the roman slave and glad ##ia ##tor ? [SEP]'],
#   'wer': [1, 0, 0, 0, 0, 0, 0]},
#  {'adversarial': ['committing what if prime geoffrey and u . s . president were seventh cousins once - removed ? red',
#    'plan weaken if prime minister and u . s . president were seventh cousins once - removed ? .',
#    'main and if prime ministers and u . s . president were seventh cousins as - removed ? !',
#    'a ran if prime minister and u . s . president were seventh cousins once - removed ? josie',
#    '##sai what if prime minister and u . s . president were seventh cousins once - removed ? aunt',
#    'maps what if prime minister and u . s . president were seventh cousins once - removed ? and',
#    'sense what if prime minister and u . s . president were eighth cousins once - removed ? !',
#    'in what if prime minister and u . s . president were first cousins once - located ? id'],
#   'original': ['[CLS] what british prime minister and u . s . president were seventh cousins once - removed ? [SEP]',
#    '[CLS] what british prime minister and u . s . president were seventh cousins once - removed ? [SEP]',
#    '[CLS] what british prime minister and u . s . president were seventh cousins once - removed ? [SEP]',
#    '[CLS] what british prime minister and u . s . president were seventh cousins once - removed ? [SEP]',
#    '[CLS] what british prime minister and u . s . president were seventh cousins once - removed ? [SEP]',
#    '[CLS] what british prime minister and u . s . president were seventh cousins once - removed ? [SEP]',
#    '[CLS] what british prime minister and u . s . president were seventh cousins once - removed ? [SEP]',
#    '[CLS] what british prime minister and u . s . president were seventh cousins once - removed ? [SEP]'],
#   'wer': [2, 2, 4, 2, 1, 1, 2, 3]},
#  {'adversarial': ['org what ice cream ##s , sea further ? ,',
#    '##mur what ice cream ##s ? sea ##s ? ,',
#    'china what ice cream ##s but sea blocks ? ,',
#    '5 what ice ice ##s ? sea grain ? .',
#    'meant what ice cream ##s ? sea paper ? ,'],
#   'original': ['[CLS] what ice cream ##s contain sea ##weed ? [SEP]',
#    '[CLS] what ice cream ##s contain sea ##weed ? [SEP]',
#    '[CLS] what ice cream ##s contain sea ##weed ? [SEP]',
#    '[CLS] what ice cream ##s contain sea ##weed ? [SEP]',
#    '[CLS] what ice cream ##s contain sea ##weed ? [SEP]'],
#   'wer': [2, 2, 2, 3, 2]},
#  {'adversarial': ['hall when do you pick winter wheat ? hazardous',
#    'the how do you plant winter wheat ? he',
#    'kolkata where do you grow winter wheat ? angel',
#    'video where do you bear winter wheat ? susan',
#    'missile how do you plant winter wheat ? you',
#    '. how do you plants winter wheat ? from',
#    'name how do you grow summer wheat ? the',
#    'ten how do you plant winter wheat ? .',
#    'peace how do you plant winter wheat ? then'],
#   'original': ['[CLS] when do you plant winter wheat ? [SEP]',
#    '[CLS] when do you plant winter wheat ? [SEP]',
#    '[CLS] when do you plant winter wheat ? [SEP]',
#    '[CLS] when do you plant winter wheat ? [SEP]',
#    '[CLS] when do you plant winter wheat ? [SEP]',
#    '[CLS] when do you plant winter wheat ? [SEP]',
#    '[CLS] when do you plant winter wheat ? [SEP]',
#    '[CLS] when do you plant winter wheat ? [SEP]',
#    '[CLS] when do you plant winter wheat ? [SEP]'],
#   'wer': [1, 1, 2, 2, 1, 2, 3, 1, 1]},
#  {'adversarial': ['. ##gu can i get information on the original 13 us colonies ? .',
#    'sikh seoul can we get information on the original 13 us colonies ? !',
#    'presented how can we get information on the original 13 us colonies ? i',
#    'developer released ? she get information on the original 13 us colonies ? what',
#    'as him can i get information on the original 13 us colonies ? contains'],
#   'original': ['[CLS] where can i get information on the original 13 us colonies ? [SEP]',
#    '[CLS] where can i get information on the original 13 us colonies ? [SEP]',
#    '[CLS] where can i get information on the original 13 us colonies ? [SEP]',
#    '[CLS] where can i get information on the original 13 us colonies ? [SEP]',
#    '[CLS] where can i get information on the original 13 us colonies ? [SEP]'],
#   'wer': [1, 2, 2, 3, 1]},
#  {'adversarial': ['persecuted what is the website for the usa journal ? ##ri',
#    'them what is the website on the usa journal ? .'],
#   'original': ['[CLS] what is the website for the usa journal ? [SEP]',
#    '[CLS] what is the website for the usa journal ? [SEP]'],
#   'wer': [0, 1]},
#  {'adversarial': ['whenever where is the higher continent ? "',
#    '##y who is the highest continent ? "',
#    'broadcasters where is the dorian continent ? first'],
#   'original': ['[CLS] what is the highest continent ? [SEP]',
#    '[CLS] what is the highest continent ? [SEP]',
#    '[CLS] what is the highest continent ? [SEP]'],
#   'wer': [2, 1, 2]},
#  {'adversarial': ['##lid what is the most populated land in the world ? ,',
#    'league what is the most populated land in the world ? ,',
#    '##ra what is the most populated country in the world ? .'],
#   'original': ['[CLS] what is the most populated city in the world ? [SEP]',
#    '[CLS] what is the most populated city in the world ? [SEP]',
#    '[CLS] what is the most populated city in the world ? [SEP]'],
#   'wer': [1, 1, 1]},
#  {'adversarial': ["power what ' s a crap ##s ##b called ? )",
#    "was what ' s a crap ##s player called ? )",
#    'roads what \' s a crap ##s player called ? "',
#    'or what \' s a crap ##s player called ? "',
#    "##so what ' s a draught ##s player called ? ."],
#   'original': ["[CLS] what ' s a crap ##s player called ? [SEP]",
#    "[CLS] what ' s a crap ##s player called ? [SEP]",
#    "[CLS] what ' s a crap ##s player called ? [SEP]",
#    "[CLS] what ' s a crap ##s player called ? [SEP]",
#    "[CLS] what ' s a crap ##s player called ? [SEP]"],
#   'wer': [1, 0, 0, 0, 1]},
#  {'adversarial': ['outdated what of house ##wife and mother of one wrote the feminine my ##sti ##que ? ##van',
#    'china what happily house ##wife and mother of three wrote the feminine my ##sti ##que ? ,'],
#   'original': ['[CLS] what suburban house ##wife and mother of three wrote the feminine my ##sti ##que ? [SEP]',
#    '[CLS] what suburban house ##wife and mother of three wrote the feminine my ##sti ##que ? [SEP]'],
#   'wer': [2, 1]},
#  {'adversarial': ['deep what are ve ##lli ##ci ##lli , riga ##ti , z ##ito ##ni , and blaze ##tti ? ?',
#    'de what are ve ##lon ##ci ##lli , riga ##ti , z ##ito ##ni , and spine ##tti ? р',
#    'helicopters what are ve ##ri ##ci ##i , naga ##ti , z ##ito ##ti , and pri ##tti ? lead',
#    'her who are ve ##zza ##ci ##lli , tristan ##ti , z ##ito ##ni , and ke ##lli ? po'],
#   'original': ['[CLS] what are ve ##rmi ##ci ##lli , riga ##ti , z ##ito ##ni , and tube ##tti ? [SEP]',
#    '[CLS] what are ve ##rmi ##ci ##lli , riga ##ti , z ##ito ##ni , and tube ##tti ? [SEP]',
#    '[CLS] what are ve ##rmi ##ci ##lli , riga ##ti , z ##ito ##ni , and tube ##tti ? [SEP]',
#    '[CLS] what are ve ##rmi ##ci ##lli , riga ##ti , z ##ito ##ni , and tube ##tti ? [SEP]'],
#   'wer': [2, 2, 5, 5]},
#  {'adversarial': ["howard what and service were the destroyers c and c ' we shot up in ? .",
#    'midland named provided delight were the destroyers p and the and had commanded up in ? ,',
#    '##olis what in sand were the destroyers a and ch . ##s shot up in ? ,',
#    'review what in ##s were the destroyers p and as mccoy , ##son up in ? .',
#    '##nin what in navy were the destroyers winston and c . and shot up in ? .',
#    'and what next song were the destroyers mackenzie and le ##ie they on up in . ,',
#    'module and next trade were the destroyers mackay and k . who or up in ? ,'],
#   'original': ['[CLS] what asian gulf were the destroyers maddox and c turner joy shot up in ? [SEP]',
#    '[CLS] what asian gulf were the destroyers maddox and c turner joy shot up in ? [SEP]',
#    '[CLS] what asian gulf were the destroyers maddox and c turner joy shot up in ? [SEP]',
#    '[CLS] what asian gulf were the destroyers maddox and c turner joy shot up in ? [SEP]',
#    '[CLS] what asian gulf were the destroyers maddox and c turner joy shot up in ? [SEP]',
#    '[CLS] what asian gulf were the destroyers maddox and c turner joy shot up in ? [SEP]',
#    '[CLS] what asian gulf were the destroyers maddox and c turner joy shot up in ? [SEP]'],
#   'wer': [5, 8, 6, 7, 5, 8, 8]},
#  {'adversarial': ['commemorate where is rider college ? the'],
#   'original': ['[CLS] where is rider college ? [SEP]'],
#   'wer': [0]},
#  {'adversarial': ["hand what was the history of valentine ' s day cards ? in",
#    "model what were the history of valentine ' s day cards ? the",
#    "thoughts what is the history of valentine ' s day cards ? shadows",
#    "finishes what were the history of valentine ' s day cards ? daddy",
#    "colts what was the history of valentine ' s day cards ? thinking",
#    "turn what is the history of valentine ' s day cards ? martin",
#    "0 what was the history of valentine ' s day cards ? jesus"],
#   'original': ["[CLS] what is the history of valentine ' s day cards ? [SEP]",
#    "[CLS] what is the history of valentine ' s day cards ? [SEP]",
#    "[CLS] what is the history of valentine ' s day cards ? [SEP]",
#    "[CLS] what is the history of valentine ' s day cards ? [SEP]",
#    "[CLS] what is the history of valentine ' s day cards ? [SEP]",
#    "[CLS] what is the history of valentine ' s day cards ? [SEP]",
#    "[CLS] what is the history of valentine ' s day cards ? [SEP]"],
#   'wer': [1, 1, 0, 1, 1, 0, 1]},
#  {'adversarial': ['global what year was the avery dennis ##on company founded ? thomas'],
#   'original': ['[CLS] what year was the avery dennis ##on company founded ? [SEP]'],
#   'wer': [0]},
#  {'adversarial': ['awkward what player squat ##s an average of 3 times in a baseball double ##head ##er ? ,',
#    'season whose player squat ##s an average of 3 times during a baseball double game up ? beau',
#    '##rd wall player squat ##s an average of 3 twice during a baseball doubles ##head 21 ? warmer',
#    'what who player squat ##s an average of 3 times during a baseball double ##head 11 ? the'],
#   'original': ['[CLS] what player squat ##s an average of 3 times during a baseball double ##head ##er ? [SEP]',
#    '[CLS] what player squat ##s an average of 3 times during a baseball double ##head ##er ? [SEP]',
#    '[CLS] what player squat ##s an average of 3 times during a baseball double ##head ##er ? [SEP]',
#    '[CLS] what player squat ##s an average of 3 times during a baseball double ##head ##er ? [SEP]'],
#   'wer': [1, 3, 4, 2]},
#  {'adversarial': ['done what does the acronym cp ##r mean ? .',
#    '##ism what does the acronym cp ##r mean ? .',
#    'us what does the acronym cp ##r mean ? dion',
#    'my what does the acronym cp ##r mean ? .',
#    '? what does the acronym cp ##r mean ? .',
#    '##boro what does the acronym cp ##r mean ? terrible',
#    'ought what does the acronym cp ##r mean ? .'],
#   'original': ['[CLS] what does the acronym cp ##r mean ? [SEP]',
#    '[CLS] what does the acronym cp ##r mean ? [SEP]',
#    '[CLS] what does the acronym cp ##r mean ? [SEP]',
#    '[CLS] what does the acronym cp ##r mean ? [SEP]',
#    '[CLS] what does the acronym cp ##r mean ? [SEP]',
#    '[CLS] what does the acronym cp ##r mean ? [SEP]',
#    '[CLS] what does the acronym cp ##r mean ? [SEP]'],
#   'wer': [0, 0, 0, 0, 0, 0, 0]},
#  {'adversarial': ['for what are those just exercises for kids to do ? .',
#    '##uca what are those good exercises for kids to do ? meaning'],
#   'original': ['[CLS] what are some good exercises for kids to do ? [SEP]',
#    '[CLS] what are some good exercises for kids to do ? [SEP]'],
#   'wer': [2, 1]},
#  {'adversarial': ["yard a co ##rg ##i is a member of what ? '",
#    'brazil a co ##rg ##i is a member of what ? "',
#    '. a co ##rg ##i is a bit of what ? "'],
#   'original': ['[CLS] a co ##rg ##i is a kind of what ? [SEP]',
#    '[CLS] a co ##rg ##i is a kind of what ? [SEP]',
#    '[CLS] a co ##rg ##i is a kind of what ? [SEP]'],
#   'wer': [1, 1, 1]},
#  {'adversarial': ['. where can he get a complete list of haven ##s in my area ? covert',
#    'nerve where can me get a complete list of showtime ##s in my area ? )',
#    'its it can i get a complete list of landlord ##s in my area ? hole',
#    'forces to can i get a complete list of showtime ##s in my area ? .',
#    '. all can i get a complete ##list of plaza ##s in my area ? "'],
#   'original': ['[CLS] where can i get a complete listing of showtime ##s in my area ? [SEP]',
#    '[CLS] where can i get a complete listing of showtime ##s in my area ? [SEP]',
#    '[CLS] where can i get a complete listing of showtime ##s in my area ? [SEP]',
#    '[CLS] where can i get a complete listing of showtime ##s in my area ? [SEP]',
#    '[CLS] where can i get a complete listing of showtime ##s in my area ? [SEP]'],
#   'wer': [3, 2, 3, 2, 3]},
#  {'adversarial': ['acute what country is the world leading supplier of cannabis ? "',
#    '2016 what countries is the nations leading supplier of cannabis ? the'],
#   'original': ['[CLS] what country is the worlds leading supplier of cannabis ? [SEP]',
#    '[CLS] what country is the worlds leading supplier of cannabis ? [SEP]'],
#   'wer': [1, 2]},
#  {'adversarial': ['. how many watts make a ki ##low kirk ? .'],
#   'original': ['[CLS] how many watts make a ki ##low ##att ? [SEP]'],
#   'wer': [1]},
#  {'adversarial': ['from what was the name of the sim that fa ##wa ##b you ##hi hi ##jack ##ed ? say',
#    '##lab but is the name of the flight that fa ##wa ##z who had hi ##jack ##ed ? you',
#    'arrangement what is the ? of the flight that fa fighter . you ##si hi ##jack ##ed ? you',
#    'season who was the name of the flight that fa ##wa ##z you wan hi ##jack ##ed ? here',
#    'hosting what took the name of the flight that fa ##wa ##z you enlisted hi ##jack ##ed ? what'],
#   'original': ['[CLS] what was the name of the flight that fa ##wa ##z you ##nis hi ##jack ##ed ? [SEP]',
#    '[CLS] what was the name of the flight that fa ##wa ##z you ##nis hi ##jack ##ed ? [SEP]',
#    '[CLS] what was the name of the flight that fa ##wa ##z you ##nis hi ##jack ##ed ? [SEP]',
#    '[CLS] what was the name of the flight that fa ##wa ##z you ##nis hi ##jack ##ed ? [SEP]',
#    '[CLS] what was the name of the flight that fa ##wa ##z you ##nis hi ##jack ##ed ? [SEP]'],
#   'wer': [3, 4, 5, 2, 2]},
#  {'adversarial': ['##ignant what non - conform ##ist abstract painter was dubbed jack the drip ##per this time ? royal',
#    '2 what non - conform ##ist abstract painter was dubbed jack the drip ##per this time ? plague',
#    'weak what non - conform ##ist abstract painter was dubbed jack the drip ##per this time ? representatives',
#    'commonwealth what non - conform ##ist abstract painter was dubbed jack the drip ##per this time ? please'],
#   'original': ['[CLS] what non - conform ##ist abstract painter was dubbed jack the drip ##per by time ? [SEP]',
#    '[CLS] what non - conform ##ist abstract painter was dubbed jack the drip ##per by time ? [SEP]',
#    '[CLS] what non - conform ##ist abstract painter was dubbed jack the drip ##per by time ? [SEP]',
#    '[CLS] what non - conform ##ist abstract painter was dubbed jack the drip ##per by time ? [SEP]'],
#   'wer': [1, 1, 1, 1]},
#  {'adversarial': ['ka what is s the capital of taiwan ? .'],
#   'original': ["[CLS] what ' s the capital of taiwan ? [SEP]"],
#   'wer': [1]},
#  {'adversarial': ["france what was john f . kennedy ' s 1960 ? song ? 1970",
#    "meant what was john f . kennedy ' s 1960 favorite song ? be",
#    "is what was john f . kennedy ' s 1960 national song ? along",
#    "another what was john f . kennedy ' s 1960 program song ? my",
#    "one what was john f . kennedy ' s 1960 standard song ? 1965",
#    "passion what was john f . kennedy ' s 1960 liberation song ? 1965",
#    "last what was john f . kennedy ' s 1960 war music ? ho",
#    ". what was john f . kennedy ' his 1960 popular song ? we"],
#   'original': ["[CLS] what was john f . kennedy ' s 1960 campaign song ? [SEP]",
#    "[CLS] what was john f . kennedy ' s 1960 campaign song ? [SEP]",
#    "[CLS] what was john f . kennedy ' s 1960 campaign song ? [SEP]",
#    "[CLS] what was john f . kennedy ' s 1960 campaign song ? [SEP]",
#    "[CLS] what was john f . kennedy ' s 1960 campaign song ? [SEP]",
#    "[CLS] what was john f . kennedy ' s 1960 campaign song ? [SEP]",
#    "[CLS] what was john f . kennedy ' s 1960 campaign song ? [SEP]",
#    "[CLS] what was john f . kennedy ' s 1960 campaign song ? [SEP]"],
#   'wer': [1, 1, 1, 1, 1, 1, 2, 2]},
#  {'adversarial': ['brewery what a motto was first a state prisoner and then a refugee in the u . s . embassy 1956 - 1971 ? .',
#    'sliced what there captain was first a state prisoner and then a refugee in the u . s . a 1956 - 1971 ? /',
#    'happening what if country was first a state prisoner and then a refugee in the u . s . embassy 1956 - 1971 ? )',
#    'basketball what if christian was first a state prisoner and then a refugee in the u . s . embassy 1956 - 1971 ? is',
#    '##d what real deal was first a state prisoner and then a refugee in the u . s . embassy 1956 - 1971 ? advancing',
#    'smashed what about skinner was first a state prisoner and then a refugee in the united . s . embassy 1956 - 1971 ? i',
#    'guardian what family who was first a state prisoner and then a refugee in the u . s . ambassador 1956 - 1971 ? :'],
#   'original': ['[CLS] what hungarian cardinal was first a state prisoner and then a refugee in the u . s . embassy 1956 - 1971 ? [SEP]',
#    '[CLS] what hungarian cardinal was first a state prisoner and then a refugee in the u . s . embassy 1956 - 1971 ? [SEP]',
#    '[CLS] what hungarian cardinal was first a state prisoner and then a refugee in the u . s . embassy 1956 - 1971 ? [SEP]',
#    '[CLS] what hungarian cardinal was first a state prisoner and then a refugee in the u . s . embassy 1956 - 1971 ? [SEP]',
#    '[CLS] what hungarian cardinal was first a state prisoner and then a refugee in the u . s . embassy 1956 - 1971 ? [SEP]',
#    '[CLS] what hungarian cardinal was first a state prisoner and then a refugee in the u . s . embassy 1956 - 1971 ? [SEP]',
#    '[CLS] what hungarian cardinal was first a state prisoner and then a refugee in the u . s . embassy 1956 - 1971 ? [SEP]'],
#   'wer': [2, 3, 2, 2, 2, 3, 3]},
#  {'adversarial': ['##omp who did sons and lovers ? judith',
#    'new who wrote sons and lovers ? .',
#    'ripping and wrote sons and lovers ? .'],
#   'original': ['[CLS] who wrote sons and lovers ? [SEP]',
#    '[CLS] who wrote sons and lovers ? [SEP]',
#    '[CLS] who wrote sons and lovers ? [SEP]'],
#   'wer': [1, 0, 1]},
#  {'adversarial': ['##d how is your corpus call ##os ##um ? ##rce',
#    '##ne what is your corpus call ##os ##um ? ##rce',
#    'provides what is your corpus call ##os ##um ? .',
#    ') where is your corpus call ##os ##um ? ##rce',
#    'australia " is your corpus call ##os ##um ? ##rce',
#    'was where is your corpus call ##os ##um ? countryside'],
#   'original': ['[CLS] where is your corpus call ##os ##um ? [SEP]',
#    '[CLS] where is your corpus call ##os ##um ? [SEP]',
#    '[CLS] where is your corpus call ##os ##um ? [SEP]',
#    '[CLS] where is your corpus call ##os ##um ? [SEP]',
#    '[CLS] where is your corpus call ##os ##um ? [SEP]',
#    '[CLS] where is your corpus call ##os ##um ? [SEP]'],
#   'wer': [1, 1, 1, 0, 1, 0]},
#  {'adversarial': ['series what were the first shaun visited by they ? ,',
#    'playing what are the first locations visited by you ? )',
#    'somali what were the first stations visited by we ? ##l',
#    'golden what were those first records far by reply ? of',
#    'the what were the last orbit visited by bouncing ? nr'],
#   'original': ['[CLS] what were the first bodies visited by spacecraft ? [SEP]',
#    '[CLS] what were the first bodies visited by spacecraft ? [SEP]',
#    '[CLS] what were the first bodies visited by spacecraft ? [SEP]',
#    '[CLS] what were the first bodies visited by spacecraft ? [SEP]',
#    '[CLS] what were the first bodies visited by spacecraft ? [SEP]'],
#   'wer': [2, 3, 2, 4, 3]},
#  {'adversarial': ['commentary in the ? , what sort of fears , fears , were there ? -',
#    'sera in the , , what sort of fears , fears , were there ? ,'],
#   'original': ['[CLS] in ad 999 , what sort of celebrations , fears , were there ? [SEP]',
#    '[CLS] in ad 999 , what sort of celebrations , fears , were there ? [SEP]'],
#   'wer': [3, 3]},
#  {'adversarial': ["cowboy what are the rules to ` ' snow golf ' ' ? '"],
#   'original': ["[CLS] what are the rules to ` ` snow golf ' ' ? [SEP]"],
#   'wer': [1]},
#  {'adversarial': ['. perspective is idle it ? didn',
#    'separately malley does idle see ? option',
#    'ᶜ quaker is idle nature ? unit',
#    '" or is idle say ? commandos',
#    'duty ) does idle interface ? pieces',
#    'eyes " means idle meal ? zhu',
#    'inclusion what does idle love ? robbery',
#    'imperialism green is idle talk ? re',
#    'diva gossip is idle say ? humanities'],
#   'original': ['[CLS] what does idle mean ? [SEP]',
#    '[CLS] what does idle mean ? [SEP]',
#    '[CLS] what does idle mean ? [SEP]',
#    '[CLS] what does idle mean ? [SEP]',
#    '[CLS] what does idle mean ? [SEP]',
#    '[CLS] what does idle mean ? [SEP]',
#    '[CLS] what does idle mean ? [SEP]',
#    '[CLS] what does idle mean ? [SEP]',
#    '[CLS] what does idle mean ? [SEP]'],
#   'wer': [3, 2, 3, 3, 2, 3, 1, 3, 3]},
#  {'adversarial': ['valley poisoning about platinum ? .',
#    'steel ##ard about platinum ? .',
#    'uc 2007 is platinum ? .',
#    'exile wales about platinum ? .',
#    '" . about platinum ? .',
#    'i of does platinum ? .',
#    'middle was good platinum ? .',
#    'u . about platinum ? .'],
#   'original': ['[CLS] what is platinum ? [SEP]',
#    '[CLS] what is platinum ? [SEP]',
#    '[CLS] what is platinum ? [SEP]',
#    '[CLS] what is platinum ? [SEP]',
#    '[CLS] what is platinum ? [SEP]',
#    '[CLS] what is platinum ? [SEP]',
#    '[CLS] what is platinum ? [SEP]',
#    '[CLS] what is platinum ? [SEP]'],
#   'wer': [2, 2, 1, 2, 2, 2, 2, 2]},
#  {'adversarial': ['york other cards are bullets ? :',
#    '14 what what are bullets ? .'],
#   'original': ['[CLS] what cards are bullets ? [SEP]',
#    '[CLS] what cards are bullets ? [SEP]'],
#   'wer': [1, 1]},
#  {'adversarial': ['grotesque how suddenly are brain cells replaced ? )',
#    '100 how how are brain cells replaced ? ?',
#    '" how often are brain cells replaced ? we',
#    "4th how how are brain cells replacement ? '"],
#   'original': ['[CLS] how often are brain cells replaced ? [SEP]',
#    '[CLS] how often are brain cells replaced ? [SEP]',
#    '[CLS] how often are brain cells replaced ? [SEP]',
#    '[CLS] how often are brain cells replaced ? [SEP]'],
#   'wer': [1, 1, 0, 2]},
#  {'adversarial': ['missing what was the u . s . highway death toll in 1969 ? acid',
#    '1752 what was the u . s . highway death toll in 1969 ? 1986'],
#   'original': ['[CLS] what was the u . s . highway death toll in 1969 ? [SEP]',
#    '[CLS] what was the u . s . highway death toll in 1969 ? [SEP]'],
#   'wer': [0, 0]},
#  {'adversarial': ['issues is the first extant trilogy of classical greek plays . nevada'],
#   'original': ['[CLS] name the only extant trilogy of classical greek plays . [SEP]'],
#   'wer': [2]},
#  {'adversarial': ['studies what is the connection between new k ##girl ##pton and dax space ? ,',
#    '##ing what is the connection between new k ##ry ##pton and dax terra ? ##chon'],
#   'original': ['[CLS] what is the connection between new k ##ry ##pton and dax ##am ? [SEP]',
#    '[CLS] what is the connection between new k ##ry ##pton and dax ##am ? [SEP]'],
#   'wer': [2, 1]},
#  {'adversarial': ['yo how was gs ##an ? ,'],
#   'original': ['[CLS] who was lac ##an ? [SEP]'],
#   'wer': [2]},
#  {'adversarial': ['. what will happen when sodium becomes contains in water ? and'],
#   'original': ['[CLS] what will happen when sodium is put in water ? [SEP]'],
#   'wer': [2]},
#  {'adversarial': ['60 what island group contains jersey , guernsey , sar board and ##aka ##m ? .'],
#   'original': ['[CLS] what island group contains jersey , guernsey , sar ##k and her ##m ? [SEP]'],
#   'wer': [2]},
#  {'adversarial': ['make what is the average weight for a man ? sweets'],
#   'original': ['[CLS] what is the average weight for a man ? [SEP]'],
#   'wer': [0]},
#  {'adversarial': ["july what does ` ` sa ##ute ' ' mean ? .",
#    "ec what does ` ` sa ##ute ' ' mean ? .",
#    "med what does ` ` sa ##ute ' ' mean ? .",
#    "1999 what does ` ` sa ##bot ` ' mean ? .",
#    "million what does ` ` sa ##ute ' ' mean ? ."],
#   'original': ["[CLS] what does ` ` sa ##ute ' ' mean ? [SEP]",
#    "[CLS] what does ` ` sa ##ute ' ' mean ? [SEP]",
#    "[CLS] what does ` ` sa ##ute ' ' mean ? [SEP]",
#    "[CLS] what does ` ` sa ##ute ' ' mean ? [SEP]",
#    "[CLS] what does ` ` sa ##ute ' ' mean ? [SEP]"],
#   'wer': [0, 0, 0, 2, 0]},
#  {'adversarial': ['buried what exactly did joseph priest ##ley use for his talent to erase pencil marks ? layer',
#    'wanted what exactly did joseph priest ##ley name for his ability to erase pencil marks ? truth',
#    'profound what exactly did joseph priest ##ley name for his ability to erase pencil marks ? return',
#    'black what business did joseph priest ##ley have for his ability to erase pencil marks ? said',
#    'ball what exactly did joseph priest ##ley name for his ability to erase pencil marks ? command',
#    'yale what exactly did joseph priest ##ley take for his ability to write pencil marks ? elite',
#    'bald what application could joseph priest ##ley use for his ability to erase pencil marks ? .',
#    'rid what napoli did joseph priest ##ley name for his ability to erase pencil marks ? hours'],
#   'original': ['[CLS] what substance did joseph priest ##ley name for its ability to erase pencil marks ? [SEP]',
#    '[CLS] what substance did joseph priest ##ley name for its ability to erase pencil marks ? [SEP]',
#    '[CLS] what substance did joseph priest ##ley name for its ability to erase pencil marks ? [SEP]',
#    '[CLS] what substance did joseph priest ##ley name for its ability to erase pencil marks ? [SEP]',
#    '[CLS] what substance did joseph priest ##ley name for its ability to erase pencil marks ? [SEP]',
#    '[CLS] what substance did joseph priest ##ley name for its ability to erase pencil marks ? [SEP]',
#    '[CLS] what substance did joseph priest ##ley name for its ability to erase pencil marks ? [SEP]',
#    '[CLS] what substance did joseph priest ##ley name for its ability to erase pencil marks ? [SEP]'],
#   'wer': [4, 2, 2, 3, 2, 4, 4, 2]},
#  {'adversarial': ["stopping what city was the target of the u . s . ' s operation urgent fury ? the",
#    "jobs what meant was the target of the u . s . ' s operation urgent fury ? latitude",
#    "demise what user was the target of the u . s . ' s operation urgent fury ? gabriel",
#    "but what - was the target of the u . s . ' s operation urgent fury ? the",
#    "christian what else was the target of the u . s . ' s operation urgent fury ? chopper",
#    "directory what college was the target of the u . s . ' s operation urgent fury ? cyclone",
#    "capabilities ##nian station was the target of the u . s . ' s operation urgent fury ? susan"],
#   'original': ["[CLS] what island was the target of the u . s . ' s operation urgent fury ? [SEP]",
#    "[CLS] what island was the target of the u . s . ' s operation urgent fury ? [SEP]",
#    "[CLS] what island was the target of the u . s . ' s operation urgent fury ? [SEP]",
#    "[CLS] what island was the target of the u . s . ' s operation urgent fury ? [SEP]",
#    "[CLS] what island was the target of the u . s . ' s operation urgent fury ? [SEP]",
#    "[CLS] what island was the target of the u . s . ' s operation urgent fury ? [SEP]",
#    "[CLS] what island was the target of the u . s . ' s operation urgent fury ? [SEP]"],
#   'wer': [1, 1, 1, 1, 1, 1, 2]},
#  {'adversarial': ["amid what does i . g . stand for ? '",
#    'teresa what does w . b . stand for ? and',
#    's what does m . g . for for ? )',
#    '##ilia what is b . g . stand for ? doug',
#    'officially what does j . g . stand for ? "',
#    "by what does f . g . hat for ? '"],
#   'original': ['[CLS] what does e . g . stand for ? [SEP]',
#    '[CLS] what does e . g . stand for ? [SEP]',
#    '[CLS] what does e . g . stand for ? [SEP]',
#    '[CLS] what does e . g . stand for ? [SEP]',
#    '[CLS] what does e . g . stand for ? [SEP]',
#    '[CLS] what does e . g . stand for ? [SEP]'],
#   'wer': [1, 2, 2, 2, 1, 2]},
#  {'adversarial': ['2 what terrorist organization was headed by donald def ##ree ##ze ? .'],
#   'original': ['[CLS] what terrorist group was headed by donald def ##ree ##ze ? [SEP]'],
#   'wer': [1]},
#  {'adversarial': ["grid what is dick clark ' s date of birth ? adventures"],
#   'original': ["[CLS] what is dick clark ' s date of birth ? [SEP]"],
#   'wer': [0]},
#  {'adversarial': ['fight what two european countries is joined by the gran san bernardo pass ? pot',
#    'objects what two european regions is joined by the gran san bernardo pass ? bonus'],
#   'original': ['[CLS] what two european countries are joined by the gran san bernardo pass ? [SEP]',
#    '[CLS] what two european countries are joined by the gran san bernardo pass ? [SEP]'],
#   'wer': [1, 2]},
#  {'adversarial': ['tv what is a le ##per ? secondary'],
#   'original': ['[CLS] what is a le ##per ? [SEP]'],
#   'wer': [0]},
#  {'adversarial': ['##zen who priest last was last seen in the parking lot of a michigan restaurant ? washington'],
#   'original': ['[CLS] what labor leader was last seen in the parking lot of a michigan restaurant ? [SEP]'],
#   'wer': [3]},
#  {'adversarial': ['things in the miller lit ##e tv commercial , what is the creature ? na',
#    'pc in the movie lit ##e tv commercial , what is the beast ? a'],
#   'original': ['[CLS] in the miller lit ##e tv commercial , who is the creature ? [SEP]',
#    '[CLS] in the miller lit ##e tv commercial , who is the creature ? [SEP]'],
#   'wer': [1, 3]},
#  {'adversarial': ['the what does this - pe ##kka sa ##en look like ? set',
#    'administrators what does zero - pe ##kka lap ##en look like ? yellow',
#    'zane what does esa - pe figure salon ##en look like ? ##ask',
#    'education what does esa - pe ##kka wall ##en look like ? set'],
#   'original': ['[CLS] what does esa - pe ##kka salon ##en look like ? [SEP]',
#    '[CLS] what does esa - pe ##kka salon ##en look like ? [SEP]',
#    '[CLS] what does esa - pe ##kka salon ##en look like ? [SEP]',
#    '[CLS] what does esa - pe ##kka salon ##en look like ? [SEP]'],
#   'wer': [2, 2, 1, 1]},
#  {'adversarial': ['faithful where are the have ##ri ##ian canals ? red',
#    '2014 i are the have ##rs ##ian canals ? not'],
#   'original': ['[CLS] where are the have ##rs ##ian canals ? [SEP]',
#    '[CLS] where are the have ##rs ##ian canals ? [SEP]'],
#   'wer': [1, 1]},
#  {'adversarial': ['local what is b ##lat ##ter ##pu ##h ! ?',
#    '##acion what is sk ##lat ##ty ##pu ##nk ? .',
# ...
#    '##ina another major diamond producer is based in botswana africa . .',
#    'locked the major diamond producer is based in south africa . the',
#    'eruption another major diamond producer is based in south africa . the',
#    '##ti the major diamond producer is based in namibia africa . ,',
#    'plateau another major diamond producer is based in johannesburg africa . the'],
#   'original': ['[CLS] which major diamond producer is based in south africa ? [SEP]',
#    '[CLS] which major diamond producer is based in south africa ? [SEP]',
#    '[CLS] which major diamond producer is based in south africa ? [SEP]',
#    '[CLS] which major diamond producer is based in south africa ? [SEP]',
#    '[CLS] which major diamond producer is based in south africa ? [SEP]',
#    '[CLS] which major diamond producer is based in south africa ? [SEP]',
#    '[CLS] which major diamond producer is based in south africa ? [SEP]',
#    '[CLS] which major diamond producer is based in south africa ? [SEP]',
#    '[CLS] which major diamond producer is based in south africa ? [SEP]',
#    '[CLS] which major diamond producer is based in south africa ? [SEP]'],
#   'wer': [2, 3, 4, 3, 2, 3, 2, 2, 3, 3]},
#  {'adversarial': ['sold maybe a south african diamond producer ? )'],
#   'original': ['[CLS] name a south african diamond producer ? [SEP]'],
#   'wer': [1]},
#  {'adversarial': [', the sort of american men are wet ? latitude',
#    'redevelopment what kind of american men are alcoholic ? latitude',
#    'economic what conform of american men are gay ? .',
#    'business what kind of american men are 1870 ? thirty',
#    'showered what colors of american men are journalists ? latitude',
#    'regulations what percentage of american men are alcoholic ? latitude',
#    'enterprises what kind of american men are gay ? cy'],
#   'original': ['[CLS] what percentage of american men are alcoholic ? [SEP]',
#    '[CLS] what percentage of american men are alcoholic ? [SEP]',
#    '[CLS] what percentage of american men are alcoholic ? [SEP]',
#    '[CLS] what percentage of american men are alcoholic ? [SEP]',
#    '[CLS] what percentage of american men are alcoholic ? [SEP]',
#    '[CLS] what percentage of american men are alcoholic ? [SEP]',
#    '[CLS] what percentage of american men are alcoholic ? [SEP]'],
#   'wer': [3, 1, 2, 2, 2, 0, 2]},
#  {'adversarial': ['honesty where do the drinks begin ? .'],
#   'original': ['[CLS] where do quality drinks begin ? [SEP]'],
#   'wer': [1]},
#  {'adversarial': ['sol how is the enough money made ? .',
#    'category how was the charity money made ? .',
#    'be how was the ranch money made ? .',
#    'promoted how was the extra money made ? .',
#    'season how was the new money made ? .',
#    'aqua how was the reward money made ? latitude',
#    'goodness how was the extra money made ? latitude',
#    'and how was the big money made ? .'],
#   'original': ['[CLS] how was the kennedy money made ? [SEP]',
#    '[CLS] how was the kennedy money made ? [SEP]',
#    '[CLS] how was the kennedy money made ? [SEP]',
#    '[CLS] how was the kennedy money made ? [SEP]',
#    '[CLS] how was the kennedy money made ? [SEP]',
#    '[CLS] how was the kennedy money made ? [SEP]',
#    '[CLS] how was the kennedy money made ? [SEP]',
#    '[CLS] how was the kennedy money made ? [SEP]'],
#   'wer': [2, 1, 1, 1, 1, 1, 1, 1]},
#  {'adversarial': ['directly what does the number 33 on the rolling rock music bottle mean ? "',
#    '##00 what does the number 33 on the rolling rock quiz bottle mean ? this',
#    'cleveland what does the number 33 on the rolling rock whiskey label mean ? )'],
#   'original': ['[CLS] what does the number 33 on the rolling rock beer bottle mean ? [SEP]',
#    '[CLS] what does the number 33 on the rolling rock beer bottle mean ? [SEP]',
#    '[CLS] what does the number 33 on the rolling rock beer bottle mean ? [SEP]'],
#   'wer': [1, 1, 2]},
#  {'adversarial': ['in . is your longest - running television series ? generations'],
#   'original': ['[CLS] what is the longest - running television series ? [SEP]'],
#   'wer': [2]},
#  {'adversarial': ["##ka where did the saying ` ` rule law proof ' ' come from ? rule",
#    "##ech where did the saying ` ` rule rule fiction ' ' come from ? law",
#    "census where did the saying ` ` rule law evil ' ' come from ? vimes",
#    "produced where did the saying ` ` rule rule wilde ' ' come from ? scotland",
#    "more where did the saying ` ` rule of departure ' ' begin from ? simpson",
#    "situation where did the saying ` ` rule to block ' ' come from ? you",
#    "rather where did the saying ` ` rule ' wrath ' ' come from ? sign"],
#   'original': ["[CLS] where did the saying ` ` rule of thumb ' ' come from ? [SEP]",
#    "[CLS] where did the saying ` ` rule of thumb ' ' come from ? [SEP]",
#    "[CLS] where did the saying ` ` rule of thumb ' ' come from ? [SEP]",
#    "[CLS] where did the saying ` ` rule of thumb ' ' come from ? [SEP]",
#    "[CLS] where did the saying ` ` rule of thumb ' ' come from ? [SEP]",
#    "[CLS] where did the saying ` ` rule of thumb ' ' come from ? [SEP]",
#    "[CLS] where did the saying ` ` rule of thumb ' ' come from ? [SEP]"],
#   'wer': [2, 2, 2, 2, 2, 2, 2]},
#  {'adversarial': ['she what russian novel ? more the 5 character is there in the napoleonic wars ? gershwin',
#    'fulham what russian romantic with more the 5 characters is mentioned in the napoleonic wars ? devi',
#    'me what russian novel with more the 5 characters is losing in the secret wars ? clair',
#    'billion what russian novel for more the 5 characters is involved in the napoleonic wars ? ##dar',
#    'æ what russian novel with more the 5 7 is present in the waterloo wars ? ##missive',
#    'of what russian novel the more of 5 characters is born in the russian wars ? les',
#    'of what russian novel and more the 5 characters is mentioning in the napoleonic wars ? crete',
#    '##rb what russian novel conflict more the 5 characters is thus in the garden wars ? ##dar',
#    ', what russian novel and more the 4 characters is here in the napoleonic wars ? ##llis'],
#   'original': ['[CLS] what russian novel embracing more the 5 characters is set in the napoleonic wars ? [SEP]',
#    '[CLS] what russian novel embracing more the 5 characters is set in the napoleonic wars ? [SEP]',
#    '[CLS] what russian novel embracing more the 5 characters is set in the napoleonic wars ? [SEP]',
#    '[CLS] what russian novel embracing more the 5 characters is set in the napoleonic wars ? [SEP]',
#    '[CLS] what russian novel embracing more the 5 characters is set in the napoleonic wars ? [SEP]',
#    '[CLS] what russian novel embracing more the 5 characters is set in the napoleonic wars ? [SEP]',
#    '[CLS] what russian novel embracing more the 5 characters is set in the napoleonic wars ? [SEP]',
#    '[CLS] what russian novel embracing more the 5 characters is set in the napoleonic wars ? [SEP]',
#    '[CLS] what russian novel embracing more the 5 characters is set in the napoleonic wars ? [SEP]'],
#   'wer': [3, 3, 3, 2, 4, 4, 2, 3, 3]},
#  {'adversarial': ['reorganized chosen first first private citizen to flew in space . henri'],
#   'original': ['[CLS] name the first private citizen to fly in space . [SEP]'],
#   'wer': [3]},
#  {'adversarial': ["##tin what caused harry ho ##udi ##ni ' s death ? ."],
#   'original': ["[CLS] what caused harry ho ##udi ##ni ' s death ? [SEP]"],
#   'wer': [0]},
#  {'adversarial': ['exchanging what was the name of the horse that fell on queen elizabeth , prince albert his s wife ? coats',
#    "relationship what was the name of the horse that fell on queen elizabeth , prince albert ' s wife ? duchess",
#    'cousin what was the name of the horse that fell on queen elizabeth , prince albert s s queen ? albert',
#    'jail what was the name of the horse that fell on queen elizabeth , prince albert his s wife ? another'],
#   'original': ["[CLS] what was the name of the horse that fell on queen elizabeth , prince albert ' s wife ? [SEP]",
#    "[CLS] what was the name of the horse that fell on queen elizabeth , prince albert ' s wife ? [SEP]",
#    "[CLS] what was the name of the horse that fell on queen elizabeth , prince albert ' s wife ? [SEP]",
#    "[CLS] what was the name of the horse that fell on queen elizabeth , prince albert ' s wife ? [SEP]"],
#   'wer': [1, 0, 2, 1]},
#  {'adversarial': [') what country comes last in an alphabet grand list ? would'],
#   'original': ['[CLS] what country comes last in an alphabet ##ical list ? [SEP]'],
#   'wer': [1]},
#  {'adversarial': ['melbourne which worse did lee marvin win the 1965 best actor oscar for ? ##sham'],
#   'original': ['[CLS] what film did lee marvin win the 1965 best actor oscar for ? [SEP]'],
#   'wer': [2]},
#  {'adversarial': ['founded armored is co ##smo ##logy ? .'],
#   'original': ['[CLS] what is co ##smo ##logy ? [SEP]'],
#   'wer': [1]},
#  {'adversarial': ["consist what ' s the highest hand for straight poker ? .",
#    "he what ' s the highest hand in straight poker ? university",
#    "connecticut what ' s the highest hand in straight poker ? established",
#    "brightly what ' s the highest hand in straight poker ? banda",
#    "swell what ' s the highest hand in straight poker ? attack",
#    "quarry what ' s the lowest hand for straight poker ? championship",
#    ". what ' s the highest hand ncaa straight poker ? against",
#    "shocked what ' s the highest hand in straight out ? ##ray",
#    "flank what ' s the highest hand in straight poker ? injured"],
#   'original': ["[CLS] what ' s the highest hand in straight poker ? [SEP]",
#    "[CLS] what ' s the highest hand in straight poker ? [SEP]",
#    "[CLS] what ' s the highest hand in straight poker ? [SEP]",
#    "[CLS] what ' s the highest hand in straight poker ? [SEP]",
#    "[CLS] what ' s the highest hand in straight poker ? [SEP]",
#    "[CLS] what ' s the highest hand in straight poker ? [SEP]",
#    "[CLS] what ' s the highest hand in straight poker ? [SEP]",
#    "[CLS] what ' s the highest hand in straight poker ? [SEP]",
#    "[CLS] what ' s the highest hand in straight poker ? [SEP]"],
#   'wer': [1, 0, 0, 0, 0, 2, 1, 1, 0]},
#  {'adversarial': ['1632 how many referees in a soccer game ? is',
#    'service how much referees in a soccer game ? blasted',
#    'providence how why referees took a soccer game ? state',
#    'fish how more referees joined a soccer game ? miracle',
#    ', how two referees gone a soccer game ? trump',
#    '##h how two referees at a soccer game ? receives',
#    'stations how many referees at a soccer game ? my'],
#   'original': ['[CLS] how many referees work a soccer game ? [SEP]',
#    '[CLS] how many referees work a soccer game ? [SEP]',
#    '[CLS] how many referees work a soccer game ? [SEP]',
#    '[CLS] how many referees work a soccer game ? [SEP]',
#    '[CLS] how many referees work a soccer game ? [SEP]',
#    '[CLS] how many referees work a soccer game ? [SEP]',
#    '[CLS] how many referees work a soccer game ? [SEP]'],
#   'wer': [1, 2, 2, 2, 2, 2, 1]},
#  {'adversarial': ['him what if general surrendered to of colonial army at saratoga ? .',
#    'nj what extraordinary general surrendered to the continental army at saratoga ? .'],
#   'original': ['[CLS] what british general surrendered to the colonial army at saratoga ? [SEP]',
#    '[CLS] what british general surrendered to the colonial army at saratoga ? [SEP]'],
#   'wer': [2, 2]},
#  {'adversarial': ['##al and according to the kin ##sey institute , is the sexual preference of four percent of american males ? .'],
#   'original': ['[CLS] what according to the kin ##sey institute , is the sexual preference of four percent of american males ? [SEP]'],
#   'wer': [1]},
#  {'adversarial': ['harris what black court did bert lo ##omi ##s in ##vent ? af',
#    'designs what broadway homer did bert lo ##omi ##s in describe ? the'],
#   'original': ['[CLS] what basketball maneuver did bert lo ##omi ##s in ##vent ? [SEP]',
#    '[CLS] what basketball maneuver did bert lo ##omi ##s in ##vent ? [SEP]'],
#   'wer': [2, 3]},
#  {'adversarial': ['five what was the rally ##ing cry of the early american revolutionaries ? .'],
#   'original': ['[CLS] what was the rally ##ing cry of the early american revolutionaries ? [SEP]'],
#   'wer': [0]},
#  {'adversarial': ['before in order from the top , the four stripes on a can of coffee are what colors ? )'],
#   'original': ['[CLS] in order from the top , the four stripes on a can of pepsi are what colors ? [SEP]'],
#   'wer': [1]},
#  {'adversarial': ['faithful what is the best way to travel in japan ? ,'],
#   'original': ['[CLS] what is the best way to travel in japan ? [SEP]'],
#   'wer': [0]},
#  {'adversarial': ['##cks what are maid - these ? what'],
#   'original': ['[CLS] what are maid - rites ? [SEP]'],
#   'wer': [1]},
#  {'adversarial': ['roberta what is the average hours per month spent online by ao % users ? the',
#    'lin what is the average hours per month spent online by ao ##l users ? ,',
#    'architecture what is the average hours per month spent online by ao ##l users ? times',
#    'interface what is the average hours per month spent online by ao + users ? ,',
#    'awards what is the average hours per month spent online by ao more users ? ,',
#    'assembly what is the average hours per month spent online by ao ##s users ? the',
#    ', what is the average hours per month spent online by ao , users ? ,',
#    '. what is the average hours per month spent online by ao ##ls users ? bangalore',
#    'departure what is the average hours per month spent online by ao ##l users ? ,',
#    'metals what is the average hours per month spent online by ao ##l users ? ,'],
#   'original': ['[CLS] what is the average hours per months spent online by ao ##l users ? [SEP]',
#    '[CLS] what is the average hours per months spent online by ao ##l users ? [SEP]',
#    '[CLS] what is the average hours per months spent online by ao ##l users ? [SEP]',
#    '[CLS] what is the average hours per months spent online by ao ##l users ? [SEP]',
#    '[CLS] what is the average hours per months spent online by ao ##l users ? [SEP]',
#    '[CLS] what is the average hours per months spent online by ao ##l users ? [SEP]',
#    '[CLS] what is the average hours per months spent online by ao ##l users ? [SEP]',
#    '[CLS] what is the average hours per months spent online by ao ##l users ? [SEP]',
#    '[CLS] what is the average hours per months spent online by ao ##l users ? [SEP]',
#    '[CLS] what is the average hours per months spent online by ao ##l users ? [SEP]'],
#   'wer': [2, 1, 1, 2, 2, 2, 2, 2, 1, 1]},
#  {'adversarial': ['of what country have the highest ratio of university students ? ,',
#    "decades what university have the highest ratio of university students ? '",
#    'planning what country have the largest ratio of university students ? .'],
#   'original': ['[CLS] what countries have the highest ratio of university students ? [SEP]',
#    '[CLS] what countries have the highest ratio of university students ? [SEP]',
#    '[CLS] what countries have the highest ratio of university students ? [SEP]'],
#   'wer': [1, 1, 2]},
#  {'adversarial': ["##bine fiery about mae west ' s last film ? ##ylus",
#    "turner . about mae west ' s last film ? .",
#    ") was about mae west ' s last film ? bored"],
#   'original': ["[CLS] what was mae west ' s last film ? [SEP]",
#    "[CLS] what was mae west ' s last film ? [SEP]",
#    "[CLS] what was mae west ' s last film ? [SEP]"],
#   'wer': [2, 2, 2]},
#  {'adversarial': ["♭ what is registered . com ' s address ? .",
#    "with what is her . com ' s address ? ."],
#   'original': ["[CLS] what is answers . com ' s address ? [SEP]",
#    "[CLS] what is answers . com ' s address ? [SEP]"],
#   'wer': [1, 1]},
#  {'adversarial': [': what are the benefits of home school ? zeke',
#    '##osaurus what are the benefits of home school ? .',
#    "logan what are the benefits of home school ? '",
#    'meet what are the benefits of home school ? ,'],
#   'original': ['[CLS] what are the benefits of home school ? [SEP]',
#    '[CLS] what are the benefits of home school ? [SEP]',
#    '[CLS] what are the benefits of home school ? [SEP]',
#    '[CLS] what are the benefits of home school ? [SEP]'],
#   'wer': [0, 0, 0, 0]}]

# %%
clean_results = []
for x in res:
    clean_results.append({
        'advs':x['advs'].detach().cpu().numpy(),
        'origs' : x['origs'].detach().cpu().numpy(),
        'scores' : x['scores'].detach().cpu().numpy(),
        'scores_orgi' : x['scores_orig'].detach().cpu().numpy()})

# %%
def collect_statistics(gumbel_samples, scores, b_input_ids, scores_orig):
    adv = delete_start_end_tokens(gumbel_samples.argmax(-1))
    scores = scores.softmax(-1).argmax(-1)[:10]
    scores_orig = scores_orig.softmax(-1).argmax(-1)[:10]
    true_class = scores_orig[0].item()
    best_attack = {
        'adv_seq': [],
        'orig_seq': [],
        'wer':[]}
    print()
    for i in adv[scores!=true_class]:
        best_attack['wer'] = calculate_wer(' '.join(y for y in [tokenizer.decode(x) for x in adv[i, :]]),
                                    ' '.join(y for y in [tokenizer.decode(x) for x in b_input_ids[:, 1:-1][0, :]]))
        best_attack['adv_seq'].append(' '.join(y for y in [tokenizer.decode(x) for x in adv[i, :]]))
        best_attack['orig_seq'].append(' '.join(y for y in [tokenizer.decode(x) for x in b_input_ids[:, 1:-1][0, :]]))
    if len(best_attack['adv_seq']) > 0:
        return best_attack #sorted(best_attack, key=lambda x: x['wer'], reverse=True)
    else:
        return 0
