# %%
# !pip3 install torchtext==0.4.0

import math
import torch
import torch.nn as nn
import torch.nn.functional as F
# Out:
# Requirement already satisfied: torchtext==0.4.0 in /usr/local/lib/python3.6/dist-packages (0.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchtext==0.4.0) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torchtext==0.4.0) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchtext==0.4.0) (1.18.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from torchtext==0.4.0) (4.41.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from torchtext==0.4.0) (1.7.0+cu101)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.4.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.4.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.4.0) (2020.11.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.4.0) (2.10)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch->torchtext==0.4.0) (0.8)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch->torchtext==0.4.0) (3.7.4.3)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->torchtext==0.4.0) (0.16.0)

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

# %%
class MaskedLanguageModel(nn.Module):

    def __init__(self, ntoken, ninp, nhead, nhid, nlayers, dropout=0.5):
        super().__init__()
        self.pos_encoder = PositionalEncoding(ninp, dropout)
        encoder_layers = nn.TransformerEncoderLayer(ninp, nhead, nhid, dropout)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, nlayers)
        self.encoder = nn.Embedding(ntoken, ninp)
        self.ninp = ninp
        self.decoder = nn.Linear(ninp, ntoken)

        self.init_weights()

    def generate_square_subsequent_mask(self, sz):
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self, src, src_mask):
        src = self.encoder(src) * math.sqrt(self.ninp)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src, src_mask)
        output = self.decoder(output)
        return output

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import torchtext
from torchtext.data.utils import get_tokenizer


TEXT = torchtext.data.Field(tokenize=get_tokenizer("basic_english"),
                            init_token='<sos>',
                            eos_token='<eos>',
                            lower=True)
train_txt, val_txt, test_txt = torchtext.datasets.WikiText2.splits(TEXT)
TEXT.build_vocab(train_txt)


def get_batches(data, bsz):
    data = TEXT.numericalize([data.examples[0].text])
    # Divide the dataset into bsz parts.
    nbatch = data.size(0) // bsz
    # Trim off any extra elements that wouldn't cleanly fit (remainders).
    data = data.narrow(0, 0, nbatch * bsz)
    # Evenly divide the data across the bsz batches.
    data = data.view(bsz, -1).t().contiguous()
    return data.to(device)

batch_size = 64
eval_batch_size = 64
train_data = get_batches(train_txt, batch_size)
val_data = get_batches(val_txt, eval_batch_size)
test_data = get_batches(test_txt, eval_batch_size)
# Out:
# downloading wikitext-2-v1.zip
# wikitext-2-v1.zip: 100%|██████████| 4.48M/4.48M [00:00<00:00, 6.49MB/s]
# extracting

# %%
bptt = 35
def get_batch(source, i):
    seq_len = min(bptt, len(source) - 1 - i)
    data = source[i:i+seq_len]
    target = source[i+1:i+1+seq_len].reshape(-1)
    return data, target

# %%
ntokens = len(TEXT.vocab.stoi) # the size of vocabulary
emsize = 64 # embedding dimension
nhid = 64 # the dimension of the feedforward network model in nn.TransformerEncoder
nlayers = 1 # the number of nn.TransformerEncoderLayer in nn.TransformerEncoder
nhead = 4 # the number of heads in the multiheadattention models
dropout = 0.1 # the dropout value
model = MaskedLanguageModel(ntokens, emsize, nhead, nhid, nlayers, dropout).to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001)
# scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95)

import time
def train():
    model.train() # Turn on the train mode
    total_loss = 0.
    start_time = time.time()
    ntokens = len(TEXT.vocab.stoi)
    src_mask = model.generate_square_subsequent_mask(bptt).to(device)
    for batch, i in enumerate(range(0, train_data.size(0) - 1, bptt)):
        data, targets = get_batch(train_data, i)
        optimizer.zero_grad()
        if data.size(0) != bptt:
            src_mask = model.generate_square_subsequent_mask(data.size(0)).to(device)
        output = model(data, src_mask)
        loss = criterion(output.view(-1, ntokens), targets)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()

        total_loss += loss.item()
        log_interval = 200
        if batch % log_interval == 0 and batch > 0:
            cur_loss = total_loss / log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | '
                  ' ms/batch {:5.2f} | '
                  'loss {:5.2f} | ppl {:8.2f}'.format(
                    epoch, batch, len(train_data) // bptt,
                    elapsed * 1000 / log_interval,
                    cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()

def evaluate(eval_model, data_source):
    eval_model.eval() # Turn on the evaluation mode
    total_loss = 0.
    ntokens = len(TEXT.vocab.stoi)
    src_mask = model.generate_square_subsequent_mask(bptt).to(device)
    with torch.no_grad():
        for i in range(0, data_source.size(0) - 1, bptt):
            data, targets = get_batch(data_source, i)
            if data.size(0) != bptt:
                src_mask = model.generate_square_subsequent_mask(data.size(0)).to(device)
            output = eval_model(data, src_mask)
            output_flat = output.view(-1, ntokens)
            total_loss += len(data) * criterion(output_flat, targets).item()
    return total_loss / (len(data_source) - 1)

# %%
best_val_loss = float("inf")
epochs = 50 # The number of epochs
best_model = None

for epoch in range(1, epochs + 1):
    epoch_start_time = time.time()
    train()
    val_loss = evaluate(model, val_data)
    print('-' * 89)
    print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
          'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                     val_loss, math.exp(val_loss)))
    print('-' * 89)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = model
# Out:
# | epoch   1 |   200/  931 batches |  ms/batch 15.15 | loss 10.34 | ppl 31051.81
# | epoch   1 |   400/  931 batches |  ms/batch 14.94 | loss 10.23 | ppl 27638.17
# | epoch   1 |   600/  931 batches |  ms/batch 14.97 | loss 10.16 | ppl 25920.22
# | epoch   1 |   800/  931 batches |  ms/batch 15.01 | loss 10.10 | ppl 24296.16
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 14.54s | valid loss  9.96 | valid ppl 21172.19
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/  931 batches |  ms/batch 15.04 | loss 10.03 | ppl 22714.88
# | epoch   2 |   400/  931 batches |  ms/batch 15.01 | loss  9.91 | ppl 20102.22
# | epoch   2 |   600/  931 batches |  ms/batch 15.01 | loss  9.84 | ppl 18681.46
# | epoch   2 |   800/  931 batches |  ms/batch 14.97 | loss  9.76 | ppl 17392.63
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 14.52s | valid loss  9.57 | valid ppl 14362.71
# -----------------------------------------------------------------------------------------
# | epoch   3 |   200/  931 batches |  ms/batch 15.04 | loss  9.68 | ppl 15921.82
# | epoch   3 |   400/  931 batches |  ms/batch 15.05 | loss  9.55 | ppl 13999.45
# | epoch   3 |   600/  931 batches |  ms/batch 14.97 | loss  9.47 | ppl 12908.65
# | epoch   3 |   800/  931 batches |  ms/batch 15.03 | loss  9.39 | ppl 11978.66
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 14.53s | valid loss  9.15 | valid ppl  9423.13
# -----------------------------------------------------------------------------------------
# | epoch   4 |   200/  931 batches |  ms/batch 15.05 | loss  9.29 | ppl 10810.06
# | epoch   4 |   400/  931 batches |  ms/batch 15.02 | loss  9.16 | ppl  9516.98
# | epoch   4 |   600/  931 batches |  ms/batch 15.06 | loss  9.08 | ppl  8774.58
# | epoch   4 |   800/  931 batches |  ms/batch 15.05 | loss  9.01 | ppl  8204.69
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 14.55s | valid loss  8.75 | valid ppl  6312.44
# -----------------------------------------------------------------------------------------
# | epoch   5 |   200/  931 batches |  ms/batch 15.06 | loss  8.92 | ppl  7484.41
# | epoch   5 |   400/  931 batches |  ms/batch 15.03 | loss  8.81 | ppl  6696.92
# | epoch   5 |   600/  931 batches |  ms/batch 14.95 | loss  8.75 | ppl  6287.39
# | epoch   5 |   800/  931 batches |  ms/batch 14.94 | loss  8.70 | ppl  6014.75
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 14.51s | valid loss  8.44 | valid ppl  4611.81
# -----------------------------------------------------------------------------------------
# | epoch   6 |   200/  931 batches |  ms/batch 15.04 | loss  8.63 | ppl  5608.20
# | epoch   6 |   400/  931 batches |  ms/batch 14.95 | loss  8.54 | ppl  5094.95
# | epoch   6 |   600/  931 batches |  ms/batch 14.98 | loss  8.48 | ppl  4836.41
# | epoch   6 |   800/  931 batches |  ms/batch 15.00 | loss  8.45 | ppl  4692.24
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 14.50s | valid loss  8.17 | valid ppl  3518.95
# -----------------------------------------------------------------------------------------
# | epoch   7 |   200/  931 batches |  ms/batch 15.07 | loss  8.39 | ppl  4421.49
# | epoch   7 |   400/  931 batches |  ms/batch 14.94 | loss  8.31 | ppl  4052.12
# | epoch   7 |   600/  931 batches |  ms/batch 14.92 | loss  8.26 | ppl  3881.19
# | epoch   7 |   800/  931 batches |  ms/batch 14.75 | loss  8.25 | ppl  3827.03
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 14.44s | valid loss  7.96 | valid ppl  2857.82
# -----------------------------------------------------------------------------------------
# | epoch   8 |   200/  931 batches |  ms/batch 14.90 | loss  8.21 | ppl  3675.02
# | epoch   8 |   400/  931 batches |  ms/batch 14.83 | loss  8.14 | ppl  3430.31
# | epoch   8 |   600/  931 batches |  ms/batch 14.87 | loss  8.11 | ppl  3333.20
# | epoch   8 |   800/  931 batches |  ms/batch 14.69 | loss  8.11 | ppl  3342.23
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 14.34s | valid loss  7.84 | valid ppl  2534.95
# -----------------------------------------------------------------------------------------
# | epoch   9 |   200/  931 batches |  ms/batch 14.83 | loss  8.09 | ppl  3267.51
# | epoch   9 |   400/  931 batches |  ms/batch 14.69 | loss  8.03 | ppl  3084.24
# | epoch   9 |   600/  931 batches |  ms/batch 14.73 | loss  8.01 | ppl  3016.14
# | epoch   9 |   800/  931 batches |  ms/batch 14.68 | loss  8.02 | ppl  3045.70
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 14.26s | valid loss  7.75 | valid ppl  2330.52
# -----------------------------------------------------------------------------------------
# | epoch  10 |   200/  931 batches |  ms/batch 14.76 | loss  8.01 | ppl  2997.50
# | epoch  10 |   400/  931 batches |  ms/batch 14.73 | loss  7.95 | ppl  2841.43
# | epoch  10 |   600/  931 batches |  ms/batch 14.72 | loss  7.93 | ppl  2781.67
# | epoch  10 |   800/  931 batches |  ms/batch 14.76 | loss  7.94 | ppl  2815.64
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 14.27s | valid loss  7.68 | valid ppl  2165.33
# -----------------------------------------------------------------------------------------
# | epoch  11 |   200/  931 batches |  ms/batch 14.77 | loss  7.93 | ppl  2778.49
# | epoch  11 |   400/  931 batches |  ms/batch 14.71 | loss  7.88 | ppl  2642.71
# | epoch  11 |   600/  931 batches |  ms/batch 14.67 | loss  7.86 | ppl  2589.13
# | epoch  11 |   800/  931 batches |  ms/batch 14.70 | loss  7.87 | ppl  2624.88
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 14.24s | valid loss  7.61 | valid ppl  2027.42
# -----------------------------------------------------------------------------------------
# | epoch  12 |   200/  931 batches |  ms/batch 14.75 | loss  7.86 | ppl  2598.73
# | epoch  12 |   400/  931 batches |  ms/batch 14.69 | loss  7.82 | ppl  2478.71
# | epoch  12 |   600/  931 batches |  ms/batch 14.70 | loss  7.80 | ppl  2429.04
# | epoch  12 |   800/  931 batches |  ms/batch 14.67 | loss  7.81 | ppl  2469.72
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 14.24s | valid loss  7.56 | valid ppl  1915.97
# -----------------------------------------------------------------------------------------
# | epoch  13 |   200/  931 batches |  ms/batch 14.77 | loss  7.80 | ppl  2452.15
# | epoch  13 |   400/  931 batches |  ms/batch 14.73 | loss  7.76 | ppl  2345.49
# | epoch  13 |   600/  931 batches |  ms/batch 14.74 | loss  7.74 | ppl  2303.05
# | epoch  13 |   800/  931 batches |  ms/batch 14.74 | loss  7.76 | ppl  2345.06
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 14.27s | valid loss  7.51 | valid ppl  1827.93
# -----------------------------------------------------------------------------------------
# | epoch  14 |   200/  931 batches |  ms/batch 14.80 | loss  7.76 | ppl  2335.04
# | epoch  14 |   400/  931 batches |  ms/batch 14.72 | loss  7.71 | ppl  2240.68
# | epoch  14 |   600/  931 batches |  ms/batch 14.77 | loss  7.70 | ppl  2199.99
# | epoch  14 |   800/  931 batches |  ms/batch 14.71 | loss  7.72 | ppl  2245.33
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 14.29s | valid loss  7.47 | valid ppl  1757.98
# -----------------------------------------------------------------------------------------
# | epoch  15 |   200/  931 batches |  ms/batch 14.87 | loss  7.71 | ppl  2241.33
# | epoch  15 |   400/  931 batches |  ms/batch 14.78 | loss  7.68 | ppl  2155.79
# | epoch  15 |   600/  931 batches |  ms/batch 14.73 | loss  7.66 | ppl  2117.16
# | epoch  15 |   800/  931 batches |  ms/batch 14.70 | loss  7.68 | ppl  2165.61
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 14.30s | valid loss  7.44 | valid ppl  1701.03
# -----------------------------------------------------------------------------------------
# | epoch  16 |   200/  931 batches |  ms/batch 14.84 | loss  7.68 | ppl  2164.26
# | epoch  16 |   400/  931 batches |  ms/batch 14.74 | loss  7.64 | ppl  2085.36
# | epoch  16 |   600/  931 batches |  ms/batch 14.77 | loss  7.63 | ppl  2049.22
# | epoch  16 |   800/  931 batches |  ms/batch 14.74 | loss  7.65 | ppl  2099.56
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 14.30s | valid loss  7.41 | valid ppl  1653.04
# -----------------------------------------------------------------------------------------
# | epoch  17 |   200/  931 batches |  ms/batch 14.78 | loss  7.65 | ppl  2101.16
# | epoch  17 |   400/  931 batches |  ms/batch 14.73 | loss  7.61 | ppl  2026.05
# | epoch  17 |   600/  931 batches |  ms/batch 14.75 | loss  7.60 | ppl  1991.93
# | epoch  17 |   800/  931 batches |  ms/batch 14.74 | loss  7.62 | ppl  2043.57
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 14.28s | valid loss  7.38 | valid ppl  1611.08
# -----------------------------------------------------------------------------------------
# | epoch  18 |   200/  931 batches |  ms/batch 14.76 | loss  7.62 | ppl  2045.21
# | epoch  18 |   400/  931 batches |  ms/batch 14.68 | loss  7.59 | ppl  1974.29
# | epoch  18 |   600/  931 batches |  ms/batch 14.69 | loss  7.57 | ppl  1940.50
# | epoch  18 |   800/  931 batches |  ms/batch 14.73 | loss  7.60 | ppl  1994.00
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 14.25s | valid loss  7.36 | valid ppl  1573.06
# -----------------------------------------------------------------------------------------
# | epoch  19 |   200/  931 batches |  ms/batch 14.77 | loss  7.60 | ppl  1995.23
# | epoch  19 |   400/  931 batches |  ms/batch 14.68 | loss  7.56 | ppl  1927.90
# | epoch  19 |   600/  931 batches |  ms/batch 14.67 | loss  7.55 | ppl  1894.46
# | epoch  19 |   800/  931 batches |  ms/batch 14.67 | loss  7.57 | ppl  1946.55
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 14.23s | valid loss  7.34 | valid ppl  1537.68
# -----------------------------------------------------------------------------------------
# | epoch  20 |   200/  931 batches |  ms/batch 14.75 | loss  7.57 | ppl  1948.18
# | epoch  20 |   400/  931 batches |  ms/batch 14.69 | loss  7.54 | ppl  1886.07
# | epoch  20 |   600/  931 batches |  ms/batch 14.68 | loss  7.52 | ppl  1851.68
# | epoch  20 |   800/  931 batches |  ms/batch 14.71 | loss  7.55 | ppl  1904.83
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 14.25s | valid loss  7.32 | valid ppl  1504.14
# -----------------------------------------------------------------------------------------
# | epoch  21 |   200/  931 batches |  ms/batch 14.78 | loss  7.55 | ppl  1905.22
# | epoch  21 |   400/  931 batches |  ms/batch 14.73 | loss  7.52 | ppl  1843.69
# | epoch  21 |   600/  931 batches |  ms/batch 14.68 | loss  7.50 | ppl  1811.91
# | epoch  21 |   800/  931 batches |  ms/batch 14.73 | loss  7.53 | ppl  1864.08
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time: 14.26s | valid loss  7.29 | valid ppl  1472.00
# -----------------------------------------------------------------------------------------
# | epoch  22 |   200/  931 batches |  ms/batch 14.80 | loss  7.53 | ppl  1863.28
# | epoch  22 |   400/  931 batches |  ms/batch 14.70 | loss  7.50 | ppl  1806.27
# | epoch  22 |   600/  931 batches |  ms/batch 14.68 | loss  7.48 | ppl  1773.53
# | epoch  22 |   800/  931 batches |  ms/batch 14.68 | loss  7.51 | ppl  1825.45
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time: 14.24s | valid loss  7.27 | valid ppl  1441.18
# -----------------------------------------------------------------------------------------
# | epoch  23 |   200/  931 batches |  ms/batch 14.76 | loss  7.51 | ppl  1824.40
# | epoch  23 |   400/  931 batches |  ms/batch 14.71 | loss  7.48 | ppl  1768.41
# | epoch  23 |   600/  931 batches |  ms/batch 14.73 | loss  7.46 | ppl  1737.14
# | epoch  23 |   800/  931 batches |  ms/batch 14.67 | loss  7.49 | ppl  1788.37
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time: 14.25s | valid loss  7.25 | valid ppl  1411.60
# -----------------------------------------------------------------------------------------
# | epoch  24 |   200/  931 batches |  ms/batch 14.78 | loss  7.49 | ppl  1786.27
# | epoch  24 |   400/  931 batches |  ms/batch 14.70 | loss  7.46 | ppl  1733.93
# | epoch  24 |   600/  931 batches |  ms/batch 14.70 | loss  7.44 | ppl  1703.20
# | epoch  24 |   800/  931 batches |  ms/batch 14.68 | loss  7.47 | ppl  1752.04
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time: 14.25s | valid loss  7.23 | valid ppl  1383.20
# -----------------------------------------------------------------------------------------
# | epoch  25 |   200/  931 batches |  ms/batch 14.77 | loss  7.47 | ppl  1751.07
# | epoch  25 |   400/  931 batches |  ms/batch 14.68 | loss  7.44 | ppl  1699.44
# | epoch  25 |   600/  931 batches |  ms/batch 14.71 | loss  7.42 | ppl  1669.43
# | epoch  25 |   800/  931 batches |  ms/batch 14.74 | loss  7.45 | ppl  1719.90
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time: 14.26s | valid loss  7.21 | valid ppl  1355.93
# -----------------------------------------------------------------------------------------
# | epoch  26 |   200/  931 batches |  ms/batch 14.76 | loss  7.45 | ppl  1717.26
# | epoch  26 |   400/  931 batches |  ms/batch 14.72 | loss  7.42 | ppl  1667.11
# | epoch  26 |   600/  931 batches |  ms/batch 14.71 | loss  7.40 | ppl  1637.17
# | epoch  26 |   800/  931 batches |  ms/batch 14.73 | loss  7.43 | ppl  1686.38
# -----------------------------------------------------------------------------------------
# | end of epoch  26 | time: 14.25s | valid loss  7.19 | valid ppl  1329.77
# -----------------------------------------------------------------------------------------
# | epoch  27 |   200/  931 batches |  ms/batch 14.82 | loss  7.43 | ppl  1682.39
# | epoch  27 |   400/  931 batches |  ms/batch 14.69 | loss  7.40 | ppl  1635.55
# | epoch  27 |   600/  931 batches |  ms/batch 14.73 | loss  7.38 | ppl  1606.25
# | epoch  27 |   800/  931 batches |  ms/batch 14.77 | loss  7.41 | ppl  1654.52
# -----------------------------------------------------------------------------------------
# | end of epoch  27 | time: 14.28s | valid loss  7.17 | valid ppl  1304.64
# -----------------------------------------------------------------------------------------
# | epoch  28 |   200/  931 batches |  ms/batch 14.86 | loss  7.41 | ppl  1651.91
# | epoch  28 |   400/  931 batches |  ms/batch 14.70 | loss  7.38 | ppl  1605.88
# | epoch  28 |   600/  931 batches |  ms/batch 14.72 | loss  7.36 | ppl  1576.85
# | epoch  28 |   800/  931 batches |  ms/batch 14.72 | loss  7.39 | ppl  1624.36
# -----------------------------------------------------------------------------------------
# | end of epoch  28 | time: 14.27s | valid loss  7.16 | valid ppl  1280.54
# -----------------------------------------------------------------------------------------
# | epoch  29 |   200/  931 batches |  ms/batch 14.77 | loss  7.39 | ppl  1620.58
# | epoch  29 |   400/  931 batches |  ms/batch 14.68 | loss  7.36 | ppl  1576.94
# | epoch  29 |   600/  931 batches |  ms/batch 14.68 | loss  7.35 | ppl  1548.77
# | epoch  29 |   800/  931 batches |  ms/batch 14.82 | loss  7.38 | ppl  1595.73
# -----------------------------------------------------------------------------------------
# | end of epoch  29 | time: 14.28s | valid loss  7.14 | valid ppl  1257.53
# -----------------------------------------------------------------------------------------
# | epoch  30 |   200/  931 batches |  ms/batch 14.89 | loss  7.37 | ppl  1591.74
# | epoch  30 |   400/  931 batches |  ms/batch 14.77 | loss  7.34 | ppl  1548.08
# | epoch  30 |   600/  931 batches |  ms/batch 14.68 | loss  7.33 | ppl  1521.45
# | epoch  30 |   800/  931 batches |  ms/batch 14.68 | loss  7.36 | ppl  1568.36
# -----------------------------------------------------------------------------------------
# | end of epoch  30 | time: 14.28s | valid loss  7.12 | valid ppl  1235.60
# -----------------------------------------------------------------------------------------
# | epoch  31 |   200/  931 batches |  ms/batch 14.74 | loss  7.36 | ppl  1564.11
# | epoch  31 |   400/  931 batches |  ms/batch 14.68 | loss  7.33 | ppl  1522.36
# | epoch  31 |   600/  931 batches |  ms/batch 14.70 | loss  7.31 | ppl  1495.97
# | epoch  31 |   800/  931 batches |  ms/batch 14.67 | loss  7.34 | ppl  1541.97
# -----------------------------------------------------------------------------------------
# | end of epoch  31 | time: 14.24s | valid loss  7.10 | valid ppl  1214.84
# -----------------------------------------------------------------------------------------
# | epoch  32 |   200/  931 batches |  ms/batch 14.77 | loss  7.34 | ppl  1537.93
# | epoch  32 |   400/  931 batches |  ms/batch 14.69 | loss  7.31 | ppl  1498.20
# | epoch  32 |   600/  931 batches |  ms/batch 14.69 | loss  7.29 | ppl  1471.66
# | epoch  32 |   800/  931 batches |  ms/batch 14.70 | loss  7.32 | ppl  1517.10
# -----------------------------------------------------------------------------------------
# | end of epoch  32 | time: 14.24s | valid loss  7.09 | valid ppl  1195.24
# -----------------------------------------------------------------------------------------
# | epoch  33 |   200/  931 batches |  ms/batch 14.81 | loss  7.32 | ppl  1512.21
# | epoch  33 |   400/  931 batches |  ms/batch 14.70 | loss  7.30 | ppl  1474.64
# | epoch  33 |   600/  931 batches |  ms/batch 14.72 | loss  7.28 | ppl  1448.65
# | epoch  33 |   800/  931 batches |  ms/batch 14.78 | loss  7.31 | ppl  1493.25
# -----------------------------------------------------------------------------------------
# | end of epoch  33 | time: 14.28s | valid loss  7.07 | valid ppl  1176.78
# -----------------------------------------------------------------------------------------
# | epoch  34 |   200/  931 batches |  ms/batch 14.78 | loss  7.31 | ppl  1489.38
# | epoch  34 |   400/  931 batches |  ms/batch 14.76 | loss  7.28 | ppl  1452.23
# | epoch  34 |   600/  931 batches |  ms/batch 14.73 | loss  7.26 | ppl  1427.04
# | epoch  34 |   800/  931 batches |  ms/batch 14.73 | loss  7.29 | ppl  1471.38
# -----------------------------------------------------------------------------------------
# | end of epoch  34 | time: 14.28s | valid loss  7.06 | valid ppl  1159.44
# -----------------------------------------------------------------------------------------
# | epoch  35 |   200/  931 batches |  ms/batch 14.84 | loss  7.29 | ppl  1467.34
# | epoch  35 |   400/  931 batches |  ms/batch 14.71 | loss  7.27 | ppl  1430.81
# | epoch  35 |   600/  931 batches |  ms/batch 14.71 | loss  7.25 | ppl  1406.48
# | epoch  35 |   800/  931 batches |  ms/batch 14.72 | loss  7.28 | ppl  1451.12
# -----------------------------------------------------------------------------------------
# | end of epoch  35 | time: 14.27s | valid loss  7.04 | valid ppl  1143.12
# -----------------------------------------------------------------------------------------
# | epoch  36 |   200/  931 batches |  ms/batch 14.77 | loss  7.28 | ppl  1446.99
# | epoch  36 |   400/  931 batches |  ms/batch 14.70 | loss  7.25 | ppl  1411.96
# | epoch  36 |   600/  931 batches |  ms/batch 14.73 | loss  7.24 | ppl  1388.48
# | epoch  36 |   800/  931 batches |  ms/batch 14.73 | loss  7.27 | ppl  1431.21
# -----------------------------------------------------------------------------------------
# | end of epoch  36 | time: 14.26s | valid loss  7.03 | valid ppl  1127.68
# -----------------------------------------------------------------------------------------
# | epoch  37 |   200/  931 batches |  ms/batch 14.78 | loss  7.26 | ppl  1427.75
# | epoch  37 |   400/  931 batches |  ms/batch 14.71 | loss  7.24 | ppl  1393.27
# | epoch  37 |   600/  931 batches |  ms/batch 14.69 | loss  7.22 | ppl  1369.45
# | epoch  37 |   800/  931 batches |  ms/batch 14.72 | loss  7.25 | ppl  1413.11
# -----------------------------------------------------------------------------------------
# | end of epoch  37 | time: 14.26s | valid loss  7.01 | valid ppl  1113.04
# -----------------------------------------------------------------------------------------
# | epoch  38 |   200/  931 batches |  ms/batch 14.81 | loss  7.25 | ppl  1408.01
# | epoch  38 |   400/  931 batches |  ms/batch 14.71 | loss  7.23 | ppl  1375.78
# | epoch  38 |   600/  931 batches |  ms/batch 14.72 | loss  7.21 | ppl  1352.38
# | epoch  38 |   800/  931 batches |  ms/batch 14.74 | loss  7.24 | ppl  1394.91
# -----------------------------------------------------------------------------------------
# | end of epoch  38 | time: 14.27s | valid loss  7.00 | valid ppl  1099.10
# -----------------------------------------------------------------------------------------
# | epoch  39 |   200/  931 batches |  ms/batch 14.81 | loss  7.24 | ppl  1391.27
# | epoch  39 |   400/  931 batches |  ms/batch 14.70 | loss  7.21 | ppl  1358.54
# | epoch  39 |   600/  931 batches |  ms/batch 14.68 | loss  7.20 | ppl  1336.43
# | epoch  39 |   800/  931 batches |  ms/batch 14.69 | loss  7.23 | ppl  1378.15
# -----------------------------------------------------------------------------------------
# | end of epoch  39 | time: 14.25s | valid loss  6.99 | valid ppl  1085.78
# -----------------------------------------------------------------------------------------
# | epoch  40 |   200/  931 batches |  ms/batch 14.77 | loss  7.23 | ppl  1374.40
# | epoch  40 |   400/  931 batches |  ms/batch 14.74 | loss  7.20 | ppl  1342.64
# | epoch  40 |   600/  931 batches |  ms/batch 14.72 | loss  7.19 | ppl  1321.08
# | epoch  40 |   800/  931 batches |  ms/batch 14.68 | loss  7.22 | ppl  1362.70
# -----------------------------------------------------------------------------------------
# | end of epoch  40 | time: 14.26s | valid loss  6.98 | valid ppl  1073.03
# -----------------------------------------------------------------------------------------
# | epoch  41 |   200/  931 batches |  ms/batch 14.76 | loss  7.21 | ppl  1358.90
# | epoch  41 |   400/  931 batches |  ms/batch 14.69 | loss  7.19 | ppl  1327.59
# | epoch  41 |   600/  931 batches |  ms/batch 14.71 | loss  7.18 | ppl  1306.75
# | epoch  41 |   800/  931 batches |  ms/batch 14.76 | loss  7.21 | ppl  1347.12
# -----------------------------------------------------------------------------------------
# | end of epoch  41 | time: 14.26s | valid loss  6.97 | valid ppl  1060.79
# -----------------------------------------------------------------------------------------
# | epoch  42 |   200/  931 batches |  ms/batch 14.76 | loss  7.20 | ppl  1343.14
# | epoch  42 |   400/  931 batches |  ms/batch 14.73 | loss  7.18 | ppl  1313.96
# | epoch  42 |   600/  931 batches |  ms/batch 14.76 | loss  7.16 | ppl  1292.39
# | epoch  42 |   800/  931 batches |  ms/batch 14.76 | loss  7.19 | ppl  1332.39
# -----------------------------------------------------------------------------------------
# | end of epoch  42 | time: 14.28s | valid loss  6.96 | valid ppl  1049.01
# -----------------------------------------------------------------------------------------
# | epoch  43 |   200/  931 batches |  ms/batch 14.82 | loss  7.19 | ppl  1328.77
# | epoch  43 |   400/  931 batches |  ms/batch 14.73 | loss  7.17 | ppl  1299.49
# | epoch  43 |   600/  931 batches |  ms/batch 14.75 | loss  7.15 | ppl  1278.54
# | epoch  43 |   800/  931 batches |  ms/batch 14.70 | loss  7.18 | ppl  1317.61
# -----------------------------------------------------------------------------------------
# | end of epoch  43 | time: 14.28s | valid loss  6.94 | valid ppl  1037.73
# -----------------------------------------------------------------------------------------
# | epoch  44 |   200/  931 batches |  ms/batch 14.80 | loss  7.18 | ppl  1313.83
# | epoch  44 |   400/  931 batches |  ms/batch 14.67 | loss  7.16 | ppl  1286.15
# | epoch  44 |   600/  931 batches |  ms/batch 14.76 | loss  7.14 | ppl  1264.94
# | epoch  44 |   800/  931 batches |  ms/batch 14.72 | loss  7.17 | ppl  1304.78
# -----------------------------------------------------------------------------------------
# | end of epoch  44 | time: 14.27s | valid loss  6.93 | valid ppl  1026.84
# -----------------------------------------------------------------------------------------
# | epoch  45 |   200/  931 batches |  ms/batch 14.78 | loss  7.17 | ppl  1301.79
# | epoch  45 |   400/  931 batches |  ms/batch 14.73 | loss  7.15 | ppl  1273.40
# | epoch  45 |   600/  931 batches |  ms/batch 14.73 | loss  7.13 | ppl  1252.89
# | epoch  45 |   800/  931 batches |  ms/batch 14.68 | loss  7.16 | ppl  1292.27
# -----------------------------------------------------------------------------------------
# | end of epoch  45 | time: 14.26s | valid loss  6.92 | valid ppl  1016.40
# -----------------------------------------------------------------------------------------
# | epoch  46 |   200/  931 batches |  ms/batch 14.80 | loss  7.16 | ppl  1287.60
# | epoch  46 |   400/  931 batches |  ms/batch 14.69 | loss  7.14 | ppl  1260.69
# | epoch  46 |   600/  931 batches |  ms/batch 14.70 | loss  7.12 | ppl  1240.85
# | epoch  46 |   800/  931 batches |  ms/batch 14.75 | loss  7.15 | ppl  1278.92
# -----------------------------------------------------------------------------------------
# | end of epoch  46 | time: 14.26s | valid loss  6.91 | valid ppl  1006.28
# -----------------------------------------------------------------------------------------
# | epoch  47 |   200/  931 batches |  ms/batch 14.76 | loss  7.15 | ppl  1276.30
# | epoch  47 |   400/  931 batches |  ms/batch 14.71 | loss  7.13 | ppl  1249.53
# | epoch  47 |   600/  931 batches |  ms/batch 14.71 | loss  7.11 | ppl  1228.81
# | epoch  47 |   800/  931 batches |  ms/batch 14.73 | loss  7.14 | ppl  1267.29
# -----------------------------------------------------------------------------------------
# | end of epoch  47 | time: 14.26s | valid loss  6.90 | valid ppl   996.56
# -----------------------------------------------------------------------------------------
# | epoch  48 |   200/  931 batches |  ms/batch 14.77 | loss  7.14 | ppl  1262.94
# | epoch  48 |   400/  931 batches |  ms/batch 14.73 | loss  7.12 | ppl  1238.25
# | epoch  48 |   600/  931 batches |  ms/batch 14.73 | loss  7.10 | ppl  1217.89
# | epoch  48 |   800/  931 batches |  ms/batch 14.72 | loss  7.14 | ppl  1255.41
# -----------------------------------------------------------------------------------------
# | end of epoch  48 | time: 14.26s | valid loss  6.89 | valid ppl   987.22
# -----------------------------------------------------------------------------------------
# | epoch  49 |   200/  931 batches |  ms/batch 14.79 | loss  7.13 | ppl  1252.37
# | epoch  49 |   400/  931 batches |  ms/batch 14.75 | loss  7.11 | ppl  1226.39
# | epoch  49 |   600/  931 batches |  ms/batch 14.71 | loss  7.10 | ppl  1206.48
# | epoch  49 |   800/  931 batches |  ms/batch 14.75 | loss  7.13 | ppl  1244.32
# -----------------------------------------------------------------------------------------
# | end of epoch  49 | time: 14.28s | valid loss  6.89 | valid ppl   978.17
# -----------------------------------------------------------------------------------------
# | epoch  50 |   200/  931 batches |  ms/batch 14.81 | loss  7.12 | ppl  1240.93
# | epoch  50 |   400/  931 batches |  ms/batch 14.77 | loss  7.10 | ppl  1215.75
# | epoch  50 |   600/  931 batches |  ms/batch 14.75 | loss  7.09 | ppl  1197.32
# | epoch  50 |   800/  931 batches |  ms/batch 14.72 | loss  7.12 | ppl  1233.54
# -----------------------------------------------------------------------------------------
# | end of epoch  50 | time: 14.29s | valid loss  6.88 | valid ppl   969.47
# -----------------------------------------------------------------------------------------

# %%
test_loss = evaluate(best_model, test_data)
print('=' * 89)
print('| End of training | test loss {:5.2f} | test ppl {:8.2f}'.format(
    test_loss, math.exp(test_loss)))
print('=' * 89)
# Out:
# =========================================================================================
# | End of training | test loss  6.81 | test ppl   905.85
# =========================================================================================

# %%
torch.save(best_model.state_dict(), 'MLM_wikitext.pt')
